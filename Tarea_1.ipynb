# %% [markdown]
# # Tarea 1 Bases de Datos 2024-1 Grupo XX

# %% [markdown]
# ## Integrantes:
# * Carlos Rabutia - 202273097-8
# * Boris Sagredo - 201904066-9
# * Luz Vilches - 202273033-1

# %% [markdown]
# ## Requisitos para Correr el Notebook
#
# Para poder utilizar este Notebook se debe tener instalado:
# - **Python 3**
# - **Jupyter**
# - La librería **ipython-sql** (Poder ejecutar sql en Jupyter Notebook)
# - PostgreSQL y su conector desde Python(**psycopg2**)
#
# **IMPORTANTE:** Este Jupyter Notebook se conectará a su servicio de Base de Datos PostgreSQL de manera **local**, por lo que **no funcionará correctamente en el entorno Google Collab.**
#
# Para instalar las dependencias, ejecute (**recuerde actualizar pip3**):

# %%
! pip3 install ipython-sql

! pip3 install psycopg2
# Out:
# Requirement already satisfied: ipython-sql in c:\users\carlo\appdata\local\programs\python\python312\lib\site-packages (0.5.0)
# Requirement already satisfied: prettytable in c:\users\carlo\appdata\local\programs\python\python312\lib\site-packages (from ipython-sql) (3.10.0)
# Requirement already satisfied: ipython in c:\users\carlo\appdata\local\programs\python\python312\lib\site-packages (from ipython-sql) (8.23.0)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\carlo\appdata\local\programs\python\python312\lib\site-packages (from ipython-sql) (2.0.29)
# Requirement already satisfied: sqlparse in c:\users\carlo\appdata\local\programs\python\python312\lib\site-packages (from ipython-sql) (0.5.0)
# Requirement already satisfied: six in c:\users\carlo\appdata\local\programs\python\python312\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in c:\users\carlo\appdata\local\programs\python\python312\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\carlo\appdata\local\programs\python\python312\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\carlo\appdata\local\programs\python\python312\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.0.3)
# Requirement already satisfied: decorator in c:\users\carlo\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\carlo\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\carlo\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\carlo\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\carlo\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (2.17.2)
# Requirement already satisfied: stack-data in c:\users\carlo\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\carlo\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: colorama in c:\users\carlo\appdata\local\programs\python\python312\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\carlo\appdata\local\programs\python\python312\lib\site-packages (from prettytable->ipython-sql) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\carlo\appdata\local\programs\python\python312\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.4)
# Requirement already satisfied: executing>=1.2.0 in c:\users\carlo\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython->ipython-sql) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\carlo\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython->ipython-sql) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\carlo\appdata\local\programs\python\python312\lib\site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Requirement already satisfied: psycopg2 in c:\users\carlo\appdata\local\programs\python\python312\lib\site-packages (2.9.9)

# %% [markdown]
# ## Importar dependencias

# %%
import random
from datetime import datetime, timedelta

#Librerías para PostgreSQL
import psycopg2

# %% [markdown]
# Para conectarse a la base de datos, completen los datos relevantes en la variable DATABASE_URL.
#
# * Cambie `user` por el usuario que utilizó en Postgres para acceder a la Base de Datos. Por defecto `postgres`.
# * Cambie `password` por la contraseña de dicho usuario. **Recuerde borrarla antes de entregar su tarea.**
# * Cambie `port` por el puerto en que se ejecuta su servicio de Base de Datos. Por defecto `5432`.
# * Cambie `database` por el nombre de la BD (Schema) que creó en Postgres.
#
# Ejemplo: `postgresql://postgres:pass_segura@localhost:5432/tarea-bd`

# %%
# %reload_ext sql
# %env DATABASE_URL=postgresql://postgres:crabu@localhost:5432/DB1
# Out:
# env: DATABASE_URL=postgresql://postgres:crabu@localhost:5432/DB1

# %% [markdown]
# Para conectarse de forma declarativa a la Base de Datos, utilice el siguiente código:

# %%
#Recuerde cambiar los valores de USER, DBNAME y PASSWORD por los mismos de la celda superior.
conn = psycopg2.connect(
   host="localhost",
   user="postgres",
   dbname='DB1',
   password="crabu"
)

print(conn)
# Out:
# <connection object at 0x0000023D0B195580; dsn: 'user=postgres password=xxx dbname=DB1 host=localhost', closed: 0>

# %% [markdown]
# ## Crear tablas
#
# Aquí inserta el código SQL que creara las tablas de la base de datos:

# %% [markdown]
# ### Tabla "Director"

# %%
# %%sql
#
# CREATE TABLE director (
# id_director INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY ,
# nombre VARCHAR(45) NOT NULL,
# edad INT
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/DB1
# (psycopg2.errors.DuplicateTable) la relación «director» ya existe
#
# [SQL: CREATE TABLE director (
# id_director INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY ,
# nombre VARCHAR(45) NOT NULL,
# edad INT
# );]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ### Tabla "Actor"

# %%
# %%sql
#
# CREATE TABLE actor (
# id_actor INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY ,
# nombre VARCHAR(45) NOT NULL,
# edad INT
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/DB1
# (psycopg2.errors.DuplicateTable) la relación «actor» ya existe
#
# [SQL: CREATE TABLE actor (
# id_actor INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY ,
# nombre VARCHAR(45) NOT NULL,
# edad INT
# );]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ### Tabla "Pelicula"

# %%
# %%sql
#
# CREATE TABLE pelicula (
#     id_pelicula INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     id_director INT NOT NULL,
#     FOREIGN KEY (id_director) REFERENCES director (id_director),
#     nombre VARCHAR(45) NOT NULL,
#     genero VARCHAR(45) NOT NULL,
#     duracion INT NOT NULL,
#     fecha_publicacion DATE NOT NULL
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/DB1
# Done.
# []

# %% [markdown]
# ### Tabla "actor_participa_en_pelicula"

# %%
# %%sql
#
# CREATE TABLE actor_participa_en_pelicula (
#     id_actor INT,
#     id_pelicula INT,
#     PRIMARY KEY (id_actor, id_pelicula),
#     FOREIGN KEY (id_actor) REFERENCES Actor (id_actor),
#     FOREIGN KEY (id_pelicula) REFERENCES pelicula (id_pelicula)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/DB1
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_director"

# %%
# %%sql
#
# CREATE TABLE premio_mejor_director (
#     id_premio INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     id_director INT,
#     FOREIGN KEY(id_director) REFERENCES director(id_director),
#     anio INT NOT NULL
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/DB1
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_actor"

# %%
# %%sql
#
# CREATE TABLE premio_mejor_actor (
#     id_premio INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     id_actor INT,
#     FOREIGN KEY(id_actor) REFERENCES actor(id_actor),
#     anio INT NOT NULL
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/DB1
# (psycopg2.errors.DuplicateTable) la relación «premio_mejor_actor» ya existe
#
# [SQL: CREATE TABLE premio_mejor_actor (
#     id_premio INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     id_actor INT,
#     FOREIGN KEY(id_actor) REFERENCES actor(id_actor),
#     anio INT NOT NULL
# );]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ### Tabla  "Premio_mejor_pelicula"

# %%
# %%sql
#
# CREATE TABLE premio_mejor_pelicula (
#     id_premio INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     id_pelicula INT,
#     FOREIGN KEY (id_pelicula) REFERENCES pelicula(id_pelicula),
#     anio INT NOT NULL
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/DB1
# (psycopg2.errors.DuplicateTable) la relación «premio_mejor_pelicula» ya existe
#
# [SQL: CREATE TABLE premio_mejor_pelicula (
#     id_premio INT PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
#     id_pelicula INT,
#     FOREIGN KEY (id_pelicula) REFERENCES pelicula(id_pelicula),
#     anio INT NOT NULL
# );]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ## Código Generador de Datos
#
# Ejecute este código para cargar datos a las tablas creadas.

# %%
import random
from datetime import date
#Prefijos y sufijos para crear nombres de peliculas aleatoriamente
prefijos = ["El misterio de", "El viaje de", "Las aventuras de", "La historia de", "El secreto de", "La leyenda de", "La búsqueda de", "El regreso de", "El tesoro de", "La odisea de", "La misión de", "La conquista de", "La travesía de", "El destino de", "El despertar de", "El último viaje de", "La venganza de", "El renacimiento de", "La rebelión de", "El vuelo de", "El descubrimiento de", "La sombra de", "La redención de", "El ritual de", "La batalla de", "El hechizo de", "El pacto de", "La profecía de", "El laberinto de", "El prisionero de", "La llegada de", "El amanecer de", "La fortuna de", "El enigma de", "La invasión de", "El resurgimiento de", "La metamorfosis de", "El eclipse de", "La danza de", "La canción de", "El lamento de", "La trampa de", "La travesura de", "El tesoro escondido de", "El vuelo mágico de", "El canto de sirena de", "El bosque encantado de", "La maldición de", "La leyenda perdida de", "La tormenta de", "El camino hacia", "El viajero de", "El guardián de", "La cripta de", "El espejismo de", "El secreto oscuro de", "La resurrección de", "La danza macabra de", "La fuga de", "La estrella fugaz de", "El grito de", "El castillo de", "La travesía sin retorno de", "La estirpe de", "La llave de", "El cuento de hadas de", "El príncipe de", "La doncella de", "El arco iris de", "La fuente de", "El refugio de", "La senda de", "La búsqueda del tesoro de", "El caballero de", "La escalada de", "La maldición del vampiro de", "La travesía del océano de"]
sufijos = ["el león", "la bailarina", "el sapo", "la estrella", "el mago", "la princesa", "el guerrero", "la criatura", "el explorador", "la bruja", "la montaña", "la isla", "el dragón", "la cueva", "el lobo", "la reina", "el rey", "la espada", "el castillo", "la flor", "la selva", "el tesoro", "la nube", "el unicornio", "la sirena", "el volcán", "la neblina", "la cascada", "el árbol", "la ciudad", "el río", "la tormenta", "la luna", "el sol", "la estrella fugaz", "el camino", "la sombra", "el laberinto", "la ola", "la caverna", "el mar", "el ángel", "la espada mágica", "el destino", "el faro", "el puente", "el horizonte", "el valle", "el puente", "la muralla", "el bosque", "la gruta", "la corona", "la aldea", "la batalla", "la noche", "el amanecer", "el atardecer", "el sueño", "la pesadilla", "el héroe", "la heroína", "la aventura", "el misterio", "la magia", "la leyenda", "la profecía", "el secreto", "el desafío", "la trampa", "la mariposa", "el jardín", "la tormenta", "la montaña", "el río", "el rincón", "el guardián", "el hechizo", "la misión", "la expedición", "la caza", "el trono", "la batalla", "la aventura", "el legado", "el enigma", "la clave", "el guardián", "el viajero", "la cripta", "el laberinto", "el abismo", "el muro", "la senda", "el laberinto", "la bruma", "la travesía", "el vuelo", "la sirena", "el hechicero", "la escuela", "la academia", "la sombra", "la estrella", "el ángel", "la gárgola", "la profecía", "la puerta", "la guerra", "el pacto", "la ley", "el viaje", "la huida", "la fortuna", "la prisión", "la cárcel", "el lamento", "la sonrisa", "el susurro", "el grito", "la fuga", "el monstruo", "la bestia", "la maraña", "el sueño", "la pesadilla", "la verdad", "el mito", "el océano", "la estrella", "el fuego", "la tierra", "el cielo", "la oscuridad", "la luz", "el caos", "la esperanza", "la promesa", "la traición", "el destino", "la salvación", "la perdición", "la soledad", "la compañía", "la amistad", "el amor", "la pasión", "la venganza", "el perdón", "el renacer", "el adiós", "la bienvenida", "la despedida", "el encuentro", "la desgracia", "la fortuna", "la guerra", "la paz", "la caída", "el renacimiento", "la resistencia", "el sacrificio", "la alianza", "el viaje", "el descubrimiento", "la revelación", "la esperanza", "la batalla", "el peligro", "la aventura", "la magia", "la pesadilla", "el misterio", "la leyenda", "la guerra", "el amor", "la traición", "la redención", "la libertad", "la prisión", "la oscuridad", "la luz", "la corrupción"]
#Nombres y apellidos para crear nombres de peliculas aleatoriamente
nombres = ["Akira", "Alessandro", "Chen", "Darius", "Emiko", "Fatemeh", "Gustavo", "Hiroko", "Isa", "Jin", "Katarina", "Lakshmi", "Mikhail", "Nina", "Omar", "Pilar", "Qiu", "Rashid", "Sakura", "Tatiana", "Umar", "Valentina", "Wang", "Xavier", "Yasmin", "Zafar", "Aarav", "Beatriz", "Chidike", "Darya", "Elif", "Fadhila", "Giovanni", "Hanako", "Ilya", "Jasmin", "Khaled", "Leticia", "Mehmet", "Nadia", "Orhan", "Parvati", "Quintus", "Rania", "Salim", "Theresa", "Ursula", "Vivek", "Wilhelmina", "Xin", "Yusef", "Zoya", "Abdullah", "Bianca", "Chiyoko", "Dmitri", "Elena", "Fabiana", "Genghis", "Han", "Irina", "Javier", "Kamala", "Leonardo", "Mina", "Natalia", "Oscar", "Patricia", "Quentin", "Rosa", "Samir", "Tatjana", "Umberto", "Valeria", "Wan", "Ximena", "Yuri", "Zara"]
apellidos = ["Abadi", "Bianchi", "Cruz", "Dutta", "Etxebarria", "Ferreira", "Gao", "Hernandez", "Ivanov", "Janssen", "Kawaguchi", "Lopez", "Montenegro", "Nguyen", "Olivares", "Petrov", "Qian", "Rodriguez", "Santos", "Tan", "Ueno", "Vargas", "Wu", "Xia", "Yilmaz", "Zhang", "Almeida", "Borges", "Carvalho", "Diniz", "Esteves", "Fernandes", "Gomes", "Henriquez", "Inácio", "Joaquim", "Lima", "Mendes", "Nogueira", "Oliveira", "Pereira", "Quintana", "Ramos", "Santana", "Teixeira", "Uchoa", "Vieira", "Xavier", "Yamamoto", "Zambrano", "Alvarez", "Barros", "Correia", "Duarte", "Estevez", "Figueiredo", "Goncalves", "Hidalgo", "Iglesias", "Jimenez", "Kumar", "Lopes", "Martinez", "Nunes", "Ortega", "Pacheco", "Queiroz", "Rocha", "Sousa", "Teles", "Urbina", "Velez", "Watanabe", "Xu", "Yan", "Zapata"]
# Definir el rango de fechas
fecha_inicial = datetime(1960, 1, 1)
fecha_final = datetime(2023, 12, 31)

# Calcular la diferencia entre las fechas inicial y final
diferencia = fecha_final - fecha_inicial

# Generar una fecha aleatoria dentro del rango
fecha_aleatoria = fecha_inicial + timedelta(days=random.randint(0, diferencia.days))

# Convertir la fecha al formato SQL DATE (YYYY-MM-DD)
fecha_sql = fecha_aleatoria.strftime('%Y-%m-%d')

cursor = conn.cursor()

premios_info = {}
directores_ids = []
for _ in range(200):
    nombre = random.choice(nombres) + " " + random.choice(apellidos)
    edad = random.randint(30,90)
    cursor.execute("INSERT INTO director (nombre, edad) VALUES (%s, %s) RETURNING id_director", (nombre, edad))
    id_director = cursor.fetchone()[0]
    directores_ids.append(id_director)
    
actores_ids = []
for _ in range(200):
    nombre = random.choice(nombres) + " " + random.choice(apellidos)
    edad = random.randint(15,70) 
    cursor.execute("INSERT INTO actor (nombre, edad) VALUES (%s, %s) RETURNING id_actor", (nombre, edad))
    id_actor = cursor.fetchone()[0]
    actores_ids.append(id_actor)

peliculas_ids = []
for _ in range(300):
    director_pelicula = random.choice(directores_ids)
    nombre = random.choice(prefijos) + " " + random.choice(sufijos)
    genero = random.choice(["Acción", "Aventura", "Animación", "Comedia", "Documental", "Drama", "Fantasía", "Terror", "Ciencia ficción", "Musical", "Misterio", "Romance", "Suspense", "Western"])
    duracion = random.randint(70,150)
    fecha_aleatoria = fecha_inicial + timedelta(days=random.randint(0, diferencia.days))
    # Convertir la fecha al formato SQL DATE (YYYY-MM-DD)
    fecha_sql = fecha_aleatoria.strftime('%Y-%m-%d')
    cursor.execute("INSERT INTO pelicula (id_director, nombre, genero, duracion, fecha_publicacion) VALUES (%s,%s,%s,%s,%s) RETURNING id_pelicula",(director_pelicula,nombre,genero,duracion,fecha_sql))
    id_pelicula = cursor.fetchone()[0]
    peliculas_ids.append(id_pelicula)
    if id_pelicula not in premios_info:
        premios_info[id_pelicula] = {}
        premios_info[id_pelicula]["año"] = fecha_aleatoria.year
        premios_info[id_pelicula]["director"] = director_pelicula
        premios_info[id_pelicula]["genero"] = genero
        premios_info[id_pelicula]["cast"] = []
        premios_info[id_pelicula]["mejor pelicula"] = "no"
    
lista_pelicula_actor = []
peliculas_actores = {}
for _ in range(500):
    peliculaID = random.choice(peliculas_ids)
    actorID = random.choice(actores_ids)
    if not (peliculaID, actorID) in lista_pelicula_actor:
        cursor.execute("INSERT INTO actor_participa_en_pelicula (id_pelicula, id_actor) VALUES (%s,%s)",(peliculaID,actorID))
        lista_pelicula_actor.append((peliculaID,actorID))
    else:
        continue


for pelicula, actor in lista_pelicula_actor:
    if pelicula in premios_info:
        premios_info[pelicula]["cast"].append(actor)

print(premios_info)
for _ in range(100):
    pelicula_al_azar = random.randint(1,300)
    tipo_de_premio = ["mejor pelicula", "mejor actor", "mejor director"]
    eleccion_premio = random.choice(tipo_de_premio)
    if eleccion_premio == "mejor director":
        if premios_info[pelicula_al_azar]["director"] != "elegido":
            director = premios_info[pelicula_al_azar]["director"]
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_director (id_director, anio) VALUES (%s,%s)",(director, año))
            premios_info[pelicula_al_azar]["director"] = "elegido"
        else:
            continue
    elif eleccion_premio == "mejor actor":
        if premios_info[pelicula_al_azar]["cast"] != []:
            actor = random.choice(premios_info[pelicula_al_azar]["cast"])
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_actor (id_actor, anio) VALUES (%s,%s)",(actor, año))
            premios_info[pelicula_al_azar]["cast"].remove(actor)
        else:
            continue
    elif eleccion_premio == "mejor pelicula":
        if premios_info[pelicula_al_azar]["mejor pelicula"] != "si":
            pelicula = pelicula_al_azar
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_pelicula (id_pelicula, anio) VALUES (%s,%s)",(pelicula, año))
            premios_info[pelicula_al_azar]["mejor pelicula"] = "si"
        else:
            continue

conn.commit()
cursor.close()
conn.close()
# Out:
# {601: {'año': 1984, 'director': 462, 'genero': 'Drama', 'cast': [402, 497], 'mejor pelicula': 'no'}, 602: {'año': 2011, 'director': 405, 'genero': 'Terror', 'cast': [], 'mejor pelicula': 'no'}, 603: {'año': 1989, 'director': 545, 'genero': 'Western', 'cast': [538, 536], 'mejor pelicula': 'no'}, 604: {'año': 2002, 'director': 542, 'genero': 'Comedia', 'cast': [], 'mejor pelicula': 'no'}, 605: {'año': 1987, 'director': 507, 'genero': 'Drama', 'cast': [422], 'mejor pelicula': 'no'}, 606: {'año': 2001, 'director': 426, 'genero': 'Suspense', 'cast': [], 'mejor pelicula': 'no'}, 607: {'año': 1977, 'director': 434, 'genero': 'Terror', 'cast': [475, 478], 'mejor pelicula': 'no'}, 608: {'año': 1986, 'director': 494, 'genero': 'Misterio', 'cast': [544, 408, 489], 'mejor pelicula': 'no'}, 609: {'año': 2008, 'director': 567, 'genero': 'Misterio', 'cast': [], 'mejor pelicula': 'no'}, 610: {'año': 1996, 'director': 522, 'genero': 'Drama', 'cast': [509, 553], 'mejor pelicula': 'no'}, 611: {'año': 1974, 'director': 422, 'genero': 'Animación', 'cast': [532], 'mejor pelicula': 'no'}, 612: {'año': 1970, 'director': 531, 'genero': 'Animación', 'cast': [407], 'mejor pelicula': 'no'}, 613: {'año': 1997, 'director': 537, 'genero': 'Western', 'cast': [428, 501, 597], 'mejor pelicula': 'no'}, 614: {'año': 1966, 'director': 540, 'genero': 'Acción', 'cast': [555, 565], 'mejor pelicula': 'no'}, 615: {'año': 1980, 'director': 512, 'genero': 'Acción', 'cast': [541], 'mejor pelicula': 'no'}, 616: {'año': 1964, 'director': 470, 'genero': 'Acción', 'cast': [], 'mejor pelicula': 'no'}, 617: {'año': 1983, 'director': 457, 'genero': 'Fantasía', 'cast': [572], 'mejor pelicula': 'no'}, 618: {'año': 1972, 'director': 562, 'genero': 'Ciencia ficción', 'cast': [415, 458, 529, 480, 428, 537], 'mejor pelicula': 'no'}, 619: {'año': 1963, 'director': 457, 'genero': 'Fantasía', 'cast': [], 'mejor pelicula': 'no'}, 620: {'año': 2018, 'director': 517, 'genero': 'Animación', 'cast': [560], 'mejor pelicula': 'no'}, 621: {'año': 2019, 'director': 594, 'genero': 'Documental', 'cast': [], 'mejor pelicula': 'no'}, 622: {'año': 2008, 'director': 422, 'genero': 'Documental', 'cast': [486], 'mejor pelicula': 'no'}, 623: {'año': 2020, 'director': 455, 'genero': 'Musical', 'cast': [], 'mejor pelicula': 'no'}, 624: {'año': 1970, 'director': 427, 'genero': 'Terror', 'cast': [], 'mejor pelicula': 'no'}, 625: {'año': 1994, 'director': 495, 'genero': 'Ciencia ficción', 'cast': [583], 'mejor pelicula': 'no'}, 626: {'año': 2005, 'director': 439, 'genero': 'Western', 'cast': [515], 'mejor pelicula': 'no'}, 627: {'año': 2002, 'director': 535, 'genero': 'Fantasía', 'cast': [420, 599, 543], 'mejor pelicula': 'no'}, 628: {'año': 2005, 'director': 548, 'genero': 'Aventura', 'cast': [471], 'mejor pelicula': 'no'}, 629: {'año': 1988, 'director': 401, 'genero': 'Fantasía', 'cast': [550, 541], 'mejor pelicula': 'no'}, 630: {'año': 2008, 'director': 552, 'genero': 'Western', 'cast': [561], 'mejor pelicula': 'no'}, 631: {'año': 1961, 'director': 540, 'genero': 'Western', 'cast': [577, 421, 592, 512], 'mejor pelicula': 'no'}, 632: {'año': 1977, 'director': 555, 'genero': 'Fantasía', 'cast': [], 'mejor pelicula': 'no'}, 633: {'año': 1995, 'director': 457, 'genero': 'Terror', 'cast': [577], 'mejor pelicula': 'no'}, 634: {'año': 2022, 'director': 480, 'genero': 'Animación', 'cast': [477, 432], 'mejor pelicula': 'no'}, 635: {'año': 2000, 'director': 441, 'genero': 'Drama', 'cast': [463], 'mejor pelicula': 'no'}, 636: {'año': 2014, 'director': 572, 'genero': 'Drama', 'cast': [], 'mejor pelicula': 'no'}, 637: {'año': 2004, 'director': 476, 'genero': 'Suspense', 'cast': [598, 558, 495, 553, 436], 'mejor pelicula': 'no'}, 638: {'año': 1972, 'director': 458, 'genero': 'Acción', 'cast': [473, 566, 423], 'mejor pelicula': 'no'}, 639: {'año': 1979, 'director': 534, 'genero': 'Western', 'cast': [406, 511, 422, 401], 'mejor pelicula': 'no'}, 640: {'año': 1992, 'director': 487, 'genero': 'Terror', 'cast': [595, 417], ' ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 99
#      97         continue
#      98 elif eleccion_premio == "mejor pelicula":
# ---> 99     if premios_info[pelicula_al_azar]["mejor pelicula"] != "si":
#     100         pelicula = pelicula_al_azar
#     101         año = premios_info[pelicula_al_azar]["año"]
#
# KeyError: 116

# %% [markdown]
# ## Consultas
#
# Escriba aquí las consultas pedidas. Recuerde agregar una descripción _breve_ de cómo funciona la solución. **Escriba las consultas de forma ordenada.**
#
# **NOTA:** Cuando en una consulta diga "X cosa" significa que ustedes deben de elegir ese X por lo que para cualquier otro X debe de funcionar de igual forma.

# %% [markdown]
# ### Consulta 1
# **Nombre de todas las películas publicadas desde el año pasado.**
#
#
# **Ejemplo:**
# |Nombre|
# |------|
# |Dune 2|
# |...|
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea_1
# 0 rows affected.
# []

# %% [markdown]
# ### Consulta 2
# **Nombre y fecha de publicación de todas las películas del género drama que hayan sido publicadas en el año 2023.**
#
#
# **Ejemplo:**
#
# |Nombre     |Fecha de publicación|
# |-----------|--------------------|
# |Oppenheimer|21-7-2023          |
# |...        |...                 |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
# Out:
# UsageError: Cell magic `%%sql` not found.

# %% [markdown]
# ### Consulta 3
# **Nombres de todos los actores que participaron en una película de género comedia.**
#
#
# **Ejemplo:**
# |Nombre       |
# |-------------|
# |Margot Robbie|
# |...          |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT
#     actor.nombre AS Nombre
# FROM
#     actor_participa_en_pelicula INNER JOIN pelicula
#     ON
#     actor_participa_en_pelicula.id_pelicula = pelicula.id_pelicula INNER JOIN actor
#     ON
#     actor_participa_en_pelicula.id_actor = actor.id_actor
# WHERE pelicula.genero ='Comedia';
# Out:
#  * postgresql://postgres:***@localhost:5432/DB1
# 44 rows affected.
# [('Abdullah Pereira', 111),
#  ('Hanako Zambrano', 28),
#  ('Orhan Cruz', 74),
#  ('Zara Pacheco', 97),
#  ('Jasmin Ivanov', 23),
#  ('Abdullah Santana', 140),
#  ('Darius Hidalgo', 140),
#  ('Umberto Iglesias', 228),
#  ('Rashid Zhang', 222),
#  ('Rashid Zhang', 214),
#  ('Salim Pacheco', 214),
#  ('Isa Correia', 23),
#  ('Ximena Queiroz', 157),
#  ('Rosa Oliveira', 198),
#  ('Umar Xia', 116),
#  ('Fadhila Xavier', 140),
#  ('Bianca Dutta', 157),
#  ('Mehmet Oliveira', 28),
#  ('Yusef Queiroz', 221),
#  ('Aarav Janssen', 246),
#  ('Zoya Hernandez', 178),
#  ('Mehmet Yilmaz', 157),
#  ('Hanako Zambrano', 201),
#  ('Rania Correia', 57),
#  ('Wan Inácio', 246),
#  ('Rashid Henriquez', 167),
#  ('Emiko Alvarez', 221),
#  ('Darya Lima', 228),
#  ('Parvati Inácio', 201),
#  ('Abdullah Wu', 178),
#  ('Elif Duarte', 222),
#  ('Omar Duarte', 246),
#  ('Omar Duarte', 214),
#  ('Abdullah Borges', 160),
#  ('Leonardo Ramos', 238),
#  ('Rania Mendes', 198),
#  ('Aarav Henriquez', 198),
#  ('Zoya Petrov', 97),
#  ('Zoya Petrov', 238),
#  ('Quintus Ivanov', 222),
#  ('Nina Zapata', 57),
#  ('Beatriz Santos', 74),
#  ('Beatriz Rocha', 121),
#  ('Beatriz Hernandez', 23)]

# %% [markdown]
# ### Consulta 4
# **Nombre y cantidad de premios ganados por cada género, ordenados de mayor a menor según la cantidad de premios.**
#
#
# **Ejemplo:**
# |Género  |Cantidad de premios|
# |--------|-------------------|
# |Drama   |99                 |
# |Fantasía|29                 |
# |...     |...                |
#
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */

# %% [markdown]
# ### Consulta 5
# **Mostrar peliculas que tengan 2 o mas actores/actrices ordenadas de mayor a menor segun la cantidad de actores/actrices.**
#
#
# **Ejemplo:**
# |Nombre     |Cantidad de actores|
# |-----------|-------------------|
# |Oppenheimer|7                  |
# |Poor Things|4                  |
# |...        |...                |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */

# %% [markdown]
# ### Consulta 6
# **Nombre de la película con la mayor brecha de edad entre el actor más joven y el actor más viejo que participen en ella, y las edades de dichos actores.** (Si hay empate, mostrar solamente uno).
#
#
# **Ejemplo:**
# |Nombre|Edad del actor más joven|Edad del actor más viejo|
# |------|------------------------|------------------------|
# |Barbie|16                      |92                      |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT
#     p.nombre AS Nombre,
#     MIN(a.edad) AS "Edad del actor más joven",
#     MAX(a.edad) AS "Edad del actor más viejo"
# FROM
#     pelicula p INNER JOIN actor_participa_en_pelicula ap
#     ON
#     p.id_pelicula = ap.id_pelicula INNER JOIN actor a
#     ON
#     ap.id_actor = a.id_actor
# GROUP BY
#     p.nombre;
# Out:
#  * postgresql://postgres:***@localhost:5432/DB1
# 237 rows affected.
# [('El tesoro escondido de la estrella', 48, 48),
#  ('El regreso de la luna', 25, 53),
#  ('La escalada de la revelación', 35, 35),
#  ('El refugio de el lamento', 18, 68),
#  ('La leyenda perdida de el laberinto', 53, 53),
#  ('La historia de el sueño', 55, 69),
#  ('La trampa de el viaje', 31, 64),
#  ('La maldición de la caída', 61, 61),
#  ('La doncella de la muralla', 23, 23),
#  ('El renacimiento de la resistencia', 56, 56),
#  ('La fuga de la tierra', 41, 66),
#  ('La tormenta de la criatura', 35, 60),
#  ('El grito de la tierra', 41, 64),
#  ('El viaje de la prisión', 52, 52),
#  ('El pacto de la gruta', 68, 68),
#  ('El caballero de la bruja', 22, 46),
#  ('El castillo de la cripta', 31, 61),
#  ('El destino de la pesadilla', 38, 45),
#  ('La maldición de el lobo', 55, 55),
#  ('La maldición de el laberinto', 19, 34),
#  ('La profecía de la esperanza', 16, 61),
#  ('La invasión de la espada mágica', 54, 54),
#  ('La historia de la pesadilla', 46, 66),
#  ('El resurgimiento de la paz', 23, 23),
#  ('La travesía sin retorno de la esperanza', 19, 20),
#  ('La cripta de la bruma', 64, 64),
#  ('El secreto de el caos', 59, 59),
#  ('El vuelo de la esperanza', 16, 54),
#  ('La travesía sin retorno de la batalla', 41, 41),
#  ('La senda de el castillo', 47, 47),
#  ('El último viaje de el misterio', 32, 38),
#  ('El caballero de el camino', 47, 55),
#  ('La búsqueda de la esperanza', 48, 69),
#  ('El príncipe de la profecía', 15, 52),
#  ('La danza de la oscuridad', 21, 64),
#  ('El despertar de la bienvenida', 55, 55),
#  ('El castillo de la verdad', 43, 50),
#  ('La misión de el océano', 28, 28),
#  ('La travesura de el dragón', 51, 60),
#  ('La rebelión de la nube', 43, 47),
#  ('El grito de la espada mágica', 31, 58),
#  ('La búsqueda del tesoro de la prisión', 46, 48),
#  ('El caballero de la gárgola', 18, 52),
#  ('La travesía sin retorno de la expedición', 36, 69),
#  ('La danza macabra de el sapo', 19, 41),
#  ('La danza de el cielo', 18, 18),
#  ('El eclipse de la corrupción', 22, 64),
#  ('El tesoro de el trono', 15, 32),
#  ('La canción de la profecía', 16, 67),
#  ('El destino de la guerra', 17, 68),
#  ('La invasión de la leyenda', 15, 48),
#  ('El espejismo de el ángel', 22, 45),
#  ('El ritual de la luz', 15, 63),
#  ('La senda de la pesadilla', 64, 64),
#  ('El destino de la batalla', 19, 58),
#  ('El misterio de la oscuridad', 55, 56),
#  ('El camino hacia la oscuridad', 32, 51),
#  ('El espejismo de la tierra', 62, 62),
#  ('El refugio de el guardián', 29, 29),
#  ('La conquista de el puente', 69, 69),
#  ('El vuelo de la luz', 57, 57),
#  ('La fortuna de el laberinto', 54, 62),
#  ('El pacto de la flor', 34, 45),
#  ('El castillo de el amor', 43, 57),
#  ('El canto de sirena de la reina', 23, 41),
#  ('El regreso de la estrella', 40, 46),
#  ('La canción de el océano', 48, 55),
#  ('La sombra de el renacer', 26, 26),
#  ('El último viaje de el viaje', 43, 54),
#  ('El hechizo de la muralla', 52, 52),
#  ('El príncipe de la huida', 51, 51),
#  ('El renacimiento de la compañía', 22, 53),
#  ('La escalada de la aventura', 15, 62),
#  ('El amanecer de la magia', 19, 69),
#  ('La canción de la traición', 64, 64),
#  ('La historia de la fuga', 55, 55),
#  ('La trampa de el camino', 17, 70),
#  ('La llave de el guardián', 44, 44),
#  ('La fuga de la pesadilla', 64, 64),
#  ('El renacimiento de la desgracia', 22, 52),
#  ('La batalla de la montaña', 56, 69),
#  ('El lamento de la ley', 51, 51),
#  ('La maldición del vampiro de la estrella fugaz', 42, 64),
#  ('El amanecer de la sombra', 26, 38),
#  ('El lamento de la luz', 19, 55),
#  ('La canción de el león', 48, 64),
#  ('El arco iris de la caída', 35, 53),
#  ('La profecía de el rey', 15, 45),
#  ('El lamento de la aventura', 31, 31),
#  ('La travesura de la criatura', 46, 46),
#  ('La venganza de la traición', 38, 65),
#  ('La fortuna de el atardecer', 17, 48),
#  ('La historia de el hechizo', 29, 29),
#  ('La estirpe de la bruma', 55, 68),
#  ('La tormenta de la noche', 25, 59),
#  ('La travesía del océano de el mago', 36, 36),
#  ('El pacto de el destino', 32, 68),
#  ('El vuelo de el destino', 23, 23),
#  ('El cuento de hadas de la expedición', 34, 34),
#  ('El enigma de la estrella fugaz', 22, 45),
#  ('El tesoro de el lamento', 22, 64),
#  ('El canto de sirena de el peligro', 17, 39),
#  ('El despertar de el grito', 41, 67),
#  ('El laberinto de la bestia', 46, 69),
#  ('La llegada de la sonrisa', 22, 61),
#  ('La profecía de el encuentro', 64, 64),
#  ('El refugio de la oscuridad', 34, 34),
#  ('El laberinto de la leyenda', 28, 60),
#  ('El misterio de la bruja', 36, 36),
#  ('La leyenda de el río', 42, 42),
#  ('El castillo de la prisión', 53, 53),
#  ('El secreto oscuro de la leyenda', 41, 41),
#  ('La maldición de la revelación', 20, 20),
#  ('La conquista de la gruta', 41, 60),
#  ('El amanecer de la prisión', 16, 48),
#  ('El príncipe de la noche', 48, 64),
#  ('El renacimiento de la gárgola', 45, 66),
#  ('El guardián de el muro', 28, 54),
#  ('La leyenda perdida de el castillo', 55, 55),
#  ('El caballero de la selva', 59, 59),
#  ('La senda de la ciudad', 44, 44),
#  ('La invasión de el adiós', 15, 15),
#  ('El enigma de el lamento', 38, 67),
#  ('La doncella de la cueva', 15, 15),
#  ('La cripta de el sol', 22, 68),
#  ('La travesura de el sueño', 47, 60),
#  ('La metamorfosis de la princesa', 36, 41),
#  ('La escalada de la pesadilla', 55, 68),
#  ('La travesura de el viaje', 23, 53),
#  ('La fuga de la soledad', 55, 58),
#  ('El refugio de el abismo', 32, 54),
#  ('El caballero de el sacrificio', 25, 69),
#  ('La danza de la estrella', 43, 51),
#  ('La odisea de el ángel', 38, 55),
#  ('La danza de la aventura', 57, 62),
#  ('La doncella de la aldea', 47, 47),
#  ('El eclipse de la oscuridad', 23, 62),
#  ('El regreso de la trampa', 17, 59),
#  ('El último viaje de la cascada', 36, 36),
#  ('El príncipe de la sombra', 39, 57),
#  ('El pacto de el caos', 64, 69),
#  ('La resurrección de el volcán', 41, 41),
#  ('El enigma de el sapo', 44, 44),
#  ('La búsqueda del tesoro de la selva', 64, 64),
#  ('El tesoro de el fuego', 18, 69),
#  ('La búsqueda del tesoro de el laberinto', 36, 47),
#  ('El vuelo de el león', 48, 48),
#  ('El ritual de la fuga', 41, 50),
#  ('La misión de el amor', 69, 69),
#  ('La leyenda de la trampa', 34, 55),
#  ('El laberinto de la mariposa', 23, 23),
#  ('La profecía de la escuela', 54, 54),
#  ('La fortuna de la magia', 19, 32),
#  ('El guardián de la maraña', 41, 67),
#  ('La maldición de la selva', 36, 60),
#  ('El renacimiento de el hechizo', 41, 68),
#  ('La travesía del océano de la puerta', 52, 52),
#  ('La senda de el adiós', 47, 47),
#  ('La rebelión de el amor', 47, 64),
#  ('La estirpe de la trampa', 42, 42),
#  ('La historia de la luz', 29, 38),
#  ('El canto de sirena de el sueño', 28, 28),
#  ('La danza macabra de la cárcel', 35, 45),
#  ('La leyenda de el enigma', 34, 53),
#  ('La fortuna de el perdón', 40, 69),
#  ('La sombra de la sonrisa', 19, 68),
#  ('El vuelo de la salvación', 38, 43),
#  ('El regreso de la ola', 33, 66),
#  ('El castillo de la espada mágica', 23, 23),
#  ('La senda de la esperanza', 29, 64),
#  ('La resurrección de la leyenda', 15, 15),
#  ('El secreto de el renacer', 35, 66),
#  ('El último viaje de la bienvenida', 19, 19),
#  ('El laberinto de la expedición', 39, 41),
#  ('El camino hacia el faro', 35, 61),
#  ('El viajero de la paz', 22, 22),
#  ('La historia de la esperanza', 69, 69),
#  ('El espejismo de el volcán', 18, 45),
#  ('La batalla de el enigma', 16, 19),
#  ('La travesura de la batalla', 53, 53),
#  ('La venganza de el descubrimiento', 32, 32),
#  ('El grito de el mito', 49, 49),
#  ('El caballero de el caos', 15, 69),
#  ('La canción de el destino', 34, 42),
#  ('La conquista de la pesadilla', 53, 69),
#  ('El viaje de la revelación', 18, 53),
#  ('La venganza de la academia', 34, 62),
#  ('El vuelo mágico de la escuela', 25, 43),
#  ('La resurrección de la bailarina', 41, 41),
#  ('La senda de la huida', 37, 68),
#  ('El resurgimiento de la revelación', 48, 48),
#  ('El vuelo de la fortuna', 57, 69),
#  ('El viaje de la luz', 51, 53),
#  ('El caballero de el mago', 38, 38),
#  ('La estirpe de la sirena', 26, 34),
#  ('El laberinto de la oscuridad', 16, 16),
#  ('La fuente de el secreto', 36, 70),
#  ('El vuelo mágico de la muralla', 17, 51),
#  ('El lamento de el sol', 28, 36),
#  ('El caballero de el amanecer', 37, 48),
#  ('La redención de el encuentro', 69, 69),
#  ('El amanecer de el viajero', 22, 22),
#  ('La búsqueda del tesoro de la isla', 34, 47),
#  ('El despertar de el valle', 15, 47),
#  ('El secreto de la aventura', 35, 35),
#  ('El enigma de la perdición', 24, 69),
#  ('El arco iris de la senda', 66, 66),
#  ('El arco iris de el cielo', 68, 68),
#  ('El hechizo de la caza', 29, 48),
#  ('La misión de el secreto', 15, 69),
#  ('El viaje de la fortuna', 50, 58),
#  ('La misión de el dragón', 23, 37),
#  ('El tesoro escondido de el cielo', 54, 55),
#  ('El pacto de la salvación', 22, 22),
#  ('La escalada de la oscuridad', 45, 67),
#  ('El viaje de el destino', 47, 70),
#  ('La fuga de la sombra', 28, 28),
#  ('El ritual de la travesía', 34, 51),
#  ('La llegada de la magia', 59, 66),
#  ('El tesoro de la montaña', 43, 62),
#  ('El eclipse de el lobo', 32, 61),
#  ('La senda de la magia', 36, 36),
#  ('El canto de sirena de la estrella', 36, 42),
#  ('La travesía sin retorno de el laberinto', 19, 19),
#  ('La metamorfosis de la traición', 53, 61),
#  ('El castillo de el secreto', 15, 15),
#  ('El pacto de la fuga', 47, 55),
#  ('La búsqueda del tesoro de la perdición', 15, 69),
#  ('El prisionero de la aldea', 43, 54),
#  ('El eclipse de la mariposa', 15, 64),
#  ('La rebelión de el árbol', 35, 57),
#  ('La fortuna de el ángel', 47, 69),
#  ('La canción de el río', 18, 18),
#  ('El príncipe de la amistad', 32, 68),
#  ('El eclipse de la montaña', 42, 42),
#  ('La historia de el jardín', 37, 54),
#  ('La maldición de la muralla', 22, 59)]

# %% [markdown]
# ### Consulta 7
# **Año de cada premio ganado por la película de mayor duración.** (Si hay empate, elegir solamente uno).
#
#
# **Ejemplo:**
# |Año |
# |----|
# |2024|
# |... |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */

# %% [markdown]
# ### Consulta 8
# **Nombre de todos los actores que han trabajado con más de un director, la cantidad de directores con las que han trabajado y el nombre de una de las películas.**
#
#
# **Ejemplo:**
# |Nombre del actor|Cantidad de directores|Nombre de una película|
# |----------------|----------------------|----------------------|
# |Cillian Murphy  |29                    |Oppenheimer           |
# |...             |...                   |...                   |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */

# %% [markdown]
# ### Consulta 9
#
# **Nombre de todos los actores que han participado sólo en películas dirigidas por el director con id\_director 1.**
#
#
# **Ejemplo:**
# |Nombre      |
# |------------|
# |Ryan Gosling|
# |...         |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
#
# SELECT DISTINCT
#     a.nombre AS Nombre
# FROM
#     actor_participa_en_pelicula ap INNER JOIN pelicula p
#     ON
#     ap.id_pelicula = p.id_pelicula INNER JOIN director d
#     ON
#     p.id_director = d.id_director INNER JOIN actor a
#     ON
#     ap.id_actor = a.id_actor
# WHERE
#     d.id_director = 1
#     AND NOT EXISTS (
#         SELECT 1
#         FROM pelicula p2
#         WHERE p2.id_director != 1
#           AND p2.id_pelicula = p.id_pelicula
#     );
# Out:
#  * postgresql://postgres:***@localhost:5432/DB1
# 2 rows affected.
# [('Fabiana Borges',), ('Valeria Qian',)]

# %% [markdown]
# ### Consulta BONUS
#
# **Nombre de todos los actores que nunca han ganado un premio, todas las películas en las que han participado y el nombre, número total de películas y número total de premios de los directores de cada película.**
#
#
# **Ejemplo:**
# |Nombre del actor|Nombre de la película|Nombre del director|Número de películas del director|Número de premios del director|
# |----------------|---------------------|-------------------|--------------------------------|-----------------------|
# |Mark Ruffalo    |Poor Things          |Yorgos Lanthimos   |4                               |0                      |
# |Saoirse Ronan   |Lady Bird            |Greta Gerwig       |20                              |1                      |
# |Saoirse Ronan   |Little Women         |Greta Gerwig       |20                              |1                      |
# |...             |...                  |...                |...                             |...                    |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
# Out:
# UsageError: Cell magic `%%sql` not found.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=cafe4e99-499e-4e36-b9fd-48e2d31e0196' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
