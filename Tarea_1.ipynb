# %% [markdown]
# # Tarea 1 Bases de Datos 2024-1 Grupo XX
#
# _Recuerde modificar esta celda y la siguiente! (Borre esta línea también)._

# %% [markdown]
# ## Integrantes:
# * Nombre Integrante 1 - Rol-1
# * Nombre Integrante 2 - Rol-2
# * Nombre Integrante 3 - Rol-3

# %% [markdown]
# ## Requisitos para Correr el Notebook
#
# Para poder utilizar este Notebook se debe tener instalado:
# - **Python 3**
# - **Jupyter**
# - La librería **ipython-sql** (Poder ejecutar sql en Jupyter Notebook)
# - PostgreSQL y su conector desde Python(**psycopg2**)
#
# **IMPORTANTE:** Este Jupyter Notebook se conectará a su servicio de Base de Datos PostgreSQL de manera **local**, por lo que **no funcionará correctamente en el entorno Google Collab.**
#
# Para instalar las dependencias, ejecute (**recuerde actualizar pip3**):

# %%
! pip3 install ipython-sql

! pip3 install psycopg2

# %% [markdown]
# ## Importar dependencias

# %%
import random
from datetime import datetime, timedelta

#Librerías para PostgreSQL
import psycopg2

# %% [markdown]
# Para conectarse a la base de datos, completen los datos relevantes en la variable DATABASE_URL.
#
# * Cambie `user` por el usuario que utilizó en Postgres para acceder a la Base de Datos. Por defecto `postgres`.
# * Cambie `password` por la contraseña de dicho usuario. **Recuerde borrarla antes de entregar su tarea.**
# * Cambie `port` por el puerto en que se ejecuta su servicio de Base de Datos. Por defecto `5432`.
# * Cambie `database` por el nombre de la BD (Schema) que creó en Postgres.
#
# Ejemplo: `postgresql://postgres:pass_segura@localhost:5432/tarea-bd`

# %%
# %reload_ext sql
# %env DATABASE_URL=postgresql://postgres:1234@localhost:5432/tarea1
# Out:
# env: DATABASE_URL=postgresql://postgres:1234@localhost:5432/tarea1

# %% [markdown]
# Para conectarse de forma declarativa a la Base de Datos, utilice el siguiente código:

# %%
#Recuerde cambiar los valores de USER, DBNAME y PASSWORD por los mismos de la celda superior.
conn = psycopg2.connect(
   host="localhost",
   user="postgres",
   dbname='tarea1',
   password="1234",
)

print(conn)
# Out:
# <connection object at 0x000002C4D51BFEF0; dsn: 'user=postgres password=xxx dbname=tarea1 host=localhost', closed: 0>

# %% [markdown]
# ## Crear tablas
#
# Aquí inserta el código SQL que creara las tablas de la base de datos:

# %% [markdown]
# ### Tabla "Director"

# %%
# %%sql
#
# CREATE TABLE director (
#     id_director INTEGER GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45) NOT NULL,
#     edad INT NOT NULL,
#     PRIMARY KEY (id_director)
# );
# Out:
# Done.
# []

# %% [markdown]
# ### Tabla "Actor"

# %%
# %%sql
# CREATE TABLE actor (
#     id_actor INTEGER GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45) NOT NULL,
#     edad INTEGER NOT NULL,
#     PRIMARY KEY (id_actor)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# Done.
# []

# %% [markdown]
# ### Tabla "Pelicula"

# %%
# %%sql
# CREATE TABLE pelicula (
#     id_pelicula INTEGER GENERATED ALWAYS AS IDENTITY,
#     id_director INTEGER,
#     nombre VARCHAR(45) NOT NULL,
#     genero VARCHAR(45) NOT NULL,
#     duracion INTEGER NOT NULL,
#     fecha_publicacion DATE NOT NULL,
#     PRIMARY KEY (id_pelicula),
#     FOREIGN KEY (id_director) REFERENCES director (id_director)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# Done.
# []

# %% [markdown]
# ### Tabla "actor_participa_en_pelicula"

# %%
# %%sql
# CREATE TABLE actor_participa_en_pelicula (
#     id_actor INTEGER,
#     id_pelicula INTEGER,
#     FOREIGN KEY (id_actor) REFERENCES Actor (id_actor),
#     FOREIGN KEY (id_pelicula) REFERENCES pelicula (id_pelicula)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_director"

# %%
# %%sql
# CREATE TABLE premio_mejor_director (
#     id_premio_dir INTEGER GENERATED ALWAYS AS IDENTITY,
#     id_director INTEGER,
#     PRIMARY KEY (id_premio_dir),
#     FOREIGN KEY (id_director) REFERENCES pelicula (id_pelicula),
#     anio INTEGER NOT NULL
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_actor"

# %%
# %%sql
# CREATE TABLE premio_mejor_actor (
#     id_premio_act INTEGER GENERATED ALWAYS AS IDENTITY,
#     id_actor INTEGER,
#     anio INTEGER NOT NULL,
#     PRIMARY KEY (id_premio_act),
#     FOREIGN KEY (id_actor) REFERENCES actor (id_actor)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_pelicula"

# %%
# %%sql
# CREATE TABLE premio_mejor_pelicula (
#     id_premio_pel INTEGER GENERATED ALWAYS AS IDENTITY,
#     id_pelicula INTEGER,
#     anio INTEGER NOT NULL,
#     PRIMARY KEY (id_premio_pel),
#     FOREIGN KEY (id_pelicula) REFERENCES pelicula (id_pelicula)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# Done.
# []

# %% [markdown]
# ## Código Generador de Datos
#
# Ejecute este código para cargar datos a las tablas creadas.

# %%
import random
from datetime import date
#Prefijos y sufijos para crear nombres de peliculas aleatoriamente
prefijos = ["El misterio de", "El viaje de", "Las aventuras de", "La historia de", "El secreto de", "La leyenda de", "La búsqueda de", "El regreso de", "El tesoro de", "La odisea de", "La misión de", "La conquista de", "La travesía de", "El destino de", "El despertar de", "El último viaje de", "La venganza de", "El renacimiento de", "La rebelión de", "El vuelo de", "El descubrimiento de", "La sombra de", "La redención de", "El ritual de", "La batalla de", "El hechizo de", "El pacto de", "La profecía de", "El laberinto de", "El prisionero de", "La llegada de", "El amanecer de", "La fortuna de", "El enigma de", "La invasión de", "El resurgimiento de", "La metamorfosis de", "El eclipse de", "La danza de", "La canción de", "El lamento de", "La trampa de", "La travesura de", "El tesoro escondido de", "El vuelo mágico de", "El canto de sirena de", "El bosque encantado de", "La maldición de", "La leyenda perdida de", "La tormenta de", "El camino hacia", "El viajero de", "El guardián de", "La cripta de", "El espejismo de", "El secreto oscuro de", "La resurrección de", "La danza macabra de", "La fuga de", "La estrella fugaz de", "El grito de", "El castillo de", "La travesía sin retorno de", "La estirpe de", "La llave de", "El cuento de hadas de", "El príncipe de", "La doncella de", "El arco iris de", "La fuente de", "El refugio de", "La senda de", "La búsqueda del tesoro de", "El caballero de", "La escalada de", "La maldición del vampiro de", "La travesía del océano de"]
sufijos = ["el león", "la bailarina", "el sapo", "la estrella", "el mago", "la princesa", "el guerrero", "la criatura", "el explorador", "la bruja", "la montaña", "la isla", "el dragón", "la cueva", "el lobo", "la reina", "el rey", "la espada", "el castillo", "la flor", "la selva", "el tesoro", "la nube", "el unicornio", "la sirena", "el volcán", "la neblina", "la cascada", "el árbol", "la ciudad", "el río", "la tormenta", "la luna", "el sol", "la estrella fugaz", "el camino", "la sombra", "el laberinto", "la ola", "la caverna", "el mar", "el ángel", "la espada mágica", "el destino", "el faro", "el puente", "el horizonte", "el valle", "el puente", "la muralla", "el bosque", "la gruta", "la corona", "la aldea", "la batalla", "la noche", "el amanecer", "el atardecer", "el sueño", "la pesadilla", "el héroe", "la heroína", "la aventura", "el misterio", "la magia", "la leyenda", "la profecía", "el secreto", "el desafío", "la trampa", "la mariposa", "el jardín", "la tormenta", "la montaña", "el río", "el rincón", "el guardián", "el hechizo", "la misión", "la expedición", "la caza", "el trono", "la batalla", "la aventura", "el legado", "el enigma", "la clave", "el guardián", "el viajero", "la cripta", "el laberinto", "el abismo", "el muro", "la senda", "el laberinto", "la bruma", "la travesía", "el vuelo", "la sirena", "el hechicero", "la escuela", "la academia", "la sombra", "la estrella", "el ángel", "la gárgola", "la profecía", "la puerta", "la guerra", "el pacto", "la ley", "el viaje", "la huida", "la fortuna", "la prisión", "la cárcel", "el lamento", "la sonrisa", "el susurro", "el grito", "la fuga", "el monstruo", "la bestia", "la maraña", "el sueño", "la pesadilla", "la verdad", "el mito", "el océano", "la estrella", "el fuego", "la tierra", "el cielo", "la oscuridad", "la luz", "el caos", "la esperanza", "la promesa", "la traición", "el destino", "la salvación", "la perdición", "la soledad", "la compañía", "la amistad", "el amor", "la pasión", "la venganza", "el perdón", "el renacer", "el adiós", "la bienvenida", "la despedida", "el encuentro", "la desgracia", "la fortuna", "la guerra", "la paz", "la caída", "el renacimiento", "la resistencia", "el sacrificio", "la alianza", "el viaje", "el descubrimiento", "la revelación", "la esperanza", "la batalla", "el peligro", "la aventura", "la magia", "la pesadilla", "el misterio", "la leyenda", "la guerra", "el amor", "la traición", "la redención", "la libertad", "la prisión", "la oscuridad", "la luz", "la corrupción"]
#Nombres y apellidos para crear nombres de peliculas aleatoriamente
nombres = ["Akira", "Alessandro", "Chen", "Darius", "Emiko", "Fatemeh", "Gustavo", "Hiroko", "Isa", "Jin", "Katarina", "Lakshmi", "Mikhail", "Nina", "Omar", "Pilar", "Qiu", "Rashid", "Sakura", "Tatiana", "Umar", "Valentina", "Wang", "Xavier", "Yasmin", "Zafar", "Aarav", "Beatriz", "Chidike", "Darya", "Elif", "Fadhila", "Giovanni", "Hanako", "Ilya", "Jasmin", "Khaled", "Leticia", "Mehmet", "Nadia", "Orhan", "Parvati", "Quintus", "Rania", "Salim", "Theresa", "Ursula", "Vivek", "Wilhelmina", "Xin", "Yusef", "Zoya", "Abdullah", "Bianca", "Chiyoko", "Dmitri", "Elena", "Fabiana", "Genghis", "Han", "Irina", "Javier", "Kamala", "Leonardo", "Mina", "Natalia", "Oscar", "Patricia", "Quentin", "Rosa", "Samir", "Tatjana", "Umberto", "Valeria", "Wan", "Ximena", "Yuri", "Zara"]
apellidos = ["Abadi", "Bianchi", "Cruz", "Dutta", "Etxebarria", "Ferreira", "Gao", "Hernandez", "Ivanov", "Janssen", "Kawaguchi", "Lopez", "Montenegro", "Nguyen", "Olivares", "Petrov", "Qian", "Rodriguez", "Santos", "Tan", "Ueno", "Vargas", "Wu", "Xia", "Yilmaz", "Zhang", "Almeida", "Borges", "Carvalho", "Diniz", "Esteves", "Fernandes", "Gomes", "Henriquez", "Inácio", "Joaquim", "Lima", "Mendes", "Nogueira", "Oliveira", "Pereira", "Quintana", "Ramos", "Santana", "Teixeira", "Uchoa", "Vieira", "Xavier", "Yamamoto", "Zambrano", "Alvarez", "Barros", "Correia", "Duarte", "Estevez", "Figueiredo", "Goncalves", "Hidalgo", "Iglesias", "Jimenez", "Kumar", "Lopes", "Martinez", "Nunes", "Ortega", "Pacheco", "Queiroz", "Rocha", "Sousa", "Teles", "Urbina", "Velez", "Watanabe", "Xu", "Yan", "Zapata"]
# Definir el rango de fechas
fecha_inicial = datetime(1960, 1, 1)
fecha_final = datetime(2023, 12, 31)

# Calcular la diferencia entre las fechas inicial y final
diferencia = fecha_final - fecha_inicial

# Generar una fecha aleatoria dentro del rango
fecha_aleatoria = fecha_inicial + timedelta(days=random.randint(0, diferencia.days))

# Convertir la fecha al formato SQL DATE (YYYY-MM-DD)
fecha_sql = fecha_aleatoria.strftime('%Y-%m-%d')

cursor = conn.cursor()

premios_info = {}
directores_ids = []
for _ in range(200):
    nombre = random.choice(nombres) + " " + random.choice(apellidos)
    edad = random.randint(30,90)
    cursor.execute("INSERT INTO director (nombre, edad) VALUES (%s, %s) RETURNING id_director", (nombre, edad))
    id_director = cursor.fetchone()[0]
    directores_ids.append(id_director)
    
actores_ids = []
for _ in range(200):
    nombre = random.choice(nombres) + " " + random.choice(apellidos)
    edad = random.randint(15,70) 
    cursor.execute("INSERT INTO actor (nombre, edad) VALUES (%s, %s) RETURNING id_actor", (nombre, edad))
    id_actor = cursor.fetchone()[0]
    actores_ids.append(id_actor)

peliculas_ids = []
for _ in range(300):
    director_pelicula = random.choice(directores_ids)
    nombre = random.choice(prefijos) + " " + random.choice(sufijos)
    genero = random.choice(["Acción", "Aventura", "Animación", "Comedia", "Documental", "Drama", "Fantasía", "Terror", "Ciencia ficción", "Musical", "Misterio", "Romance", "Suspense", "Western"])
    duracion = random.randint(70,150)
    fecha_aleatoria = fecha_inicial + timedelta(days=random.randint(0, diferencia.days))
    # Convertir la fecha al formato SQL DATE (YYYY-MM-DD)
    fecha_sql = fecha_aleatoria.strftime('%Y-%m-%d')
    cursor.execute("INSERT INTO pelicula (id_director, nombre, genero, duracion, fecha_publicacion) VALUES (%s,%s,%s,%s,%s) RETURNING id_pelicula",(director_pelicula,nombre,genero,duracion,fecha_sql))
    id_pelicula = cursor.fetchone()[0]
    peliculas_ids.append(id_pelicula)
    if id_pelicula not in premios_info:
        premios_info[id_pelicula] = {}
        premios_info[id_pelicula]["año"] = fecha_aleatoria.year
        premios_info[id_pelicula]["director"] = director_pelicula
        premios_info[id_pelicula]["genero"] = genero
        premios_info[id_pelicula]["cast"] = []
        premios_info[id_pelicula]["mejor pelicula"] = "no"
    
lista_pelicula_actor = []
peliculas_actores = {}
for _ in range(500):
    peliculaID = random.choice(peliculas_ids)
    actorID = random.choice(actores_ids)
    if not (peliculaID, actorID) in lista_pelicula_actor:
        cursor.execute("INSERT INTO actor_participa_en_pelicula (id_pelicula, id_actor) VALUES (%s,%s)",(peliculaID,actorID))
        lista_pelicula_actor.append((peliculaID,actorID))
    else:
        continue


for pelicula, actor in lista_pelicula_actor:
    if pelicula in premios_info:
        premios_info[pelicula]["cast"].append(actor)

print(premios_info)
for _ in range(100):
    pelicula_al_azar = random.randint(1,300)
    tipo_de_premio = ["mejor pelicula", "mejor actor", "mejor director"]
    eleccion_premio = random.choice(tipo_de_premio)
    if eleccion_premio == "mejor director":
        if premios_info[pelicula_al_azar]["director"] != "elegido":
            director = premios_info[pelicula_al_azar]["director"]
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_director (id_director, anio) VALUES (%s,%s)",(director, año))
            premios_info[pelicula_al_azar]["director"] = "elegido"
        else:
            continue
    elif eleccion_premio == "mejor actor":
        if premios_info[pelicula_al_azar]["cast"] != []:
            actor = random.choice(premios_info[pelicula_al_azar]["cast"])
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_actor (id_actor, anio) VALUES (%s,%s)",(actor, año))
            premios_info[pelicula_al_azar]["cast"].remove(actor)
        else:
            continue
    elif eleccion_premio == "mejor pelicula":
        if premios_info[pelicula_al_azar]["mejor pelicula"] != "si":
            pelicula = pelicula_al_azar
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_pelicula (id_pelicula, anio) VALUES (%s,%s)",(pelicula, año))
            premios_info[pelicula_al_azar]["mejor pelicula"] = "si"
        else:
            continue

conn.commit()
cursor.close()
conn.close()
# Out:
# {1: {'año': 1966, 'director': 179, 'genero': 'Drama', 'cast': [], 'mejor pelicula': 'no'}, 2: {'año': 2000, 'director': 63, 'genero': 'Documental', 'cast': [8], 'mejor pelicula': 'no'}, 3: {'año': 1964, 'director': 86, 'genero': 'Comedia', 'cast': [3, 48], 'mejor pelicula': 'no'}, 4: {'año': 2021, 'director': 19, 'genero': 'Comedia', 'cast': [138, 100, 114, 139], 'mejor pelicula': 'no'}, 5: {'año': 1969, 'director': 22, 'genero': 'Acción', 'cast': [], 'mejor pelicula': 'no'}, 6: {'año': 1974, 'director': 25, 'genero': 'Comedia', 'cast': [164], 'mejor pelicula': 'no'}, 7: {'año': 1974, 'director': 126, 'genero': 'Musical', 'cast': [38], 'mejor pelicula': 'no'}, 8: {'año': 1969, 'director': 133, 'genero': 'Misterio', 'cast': [55], 'mejor pelicula': 'no'}, 9: {'año': 1984, 'director': 47, 'genero': 'Western', 'cast': [93, 107], 'mejor pelicula': 'no'}, 10: {'año': 2009, 'director': 99, 'genero': 'Aventura', 'cast': [111], 'mejor pelicula': 'no'}, 11: {'año': 2014, 'director': 173, 'genero': 'Animación', 'cast': [140], 'mejor pelicula': 'no'}, 12: {'año': 2010, 'director': 130, 'genero': 'Acción', 'cast': [157, 175], 'mejor pelicula': 'no'}, 13: {'año': 1976, 'director': 70, 'genero': 'Musical', 'cast': [12, 100, 64], 'mejor pelicula': 'no'}, 14: {'año': 2016, 'director': 200, 'genero': 'Fantasía', 'cast': [8, 62, 164], 'mejor pelicula': 'no'}, 15: {'año': 1993, 'director': 134, 'genero': 'Terror', 'cast': [153], 'mejor pelicula': 'no'}, 16: {'año': 2001, 'director': 8, 'genero': 'Drama', 'cast': [], 'mejor pelicula': 'no'}, 17: {'año': 1973, 'director': 130, 'genero': 'Ciencia ficción', 'cast': [], 'mejor pelicula': 'no'}, 18: {'año': 1983, 'director': 92, 'genero': 'Western', 'cast': [], 'mejor pelicula': 'no'}, 19: {'año': 1979, 'director': 186, 'genero': 'Comedia', 'cast': [51], 'mejor pelicula': 'no'}, 20: {'año': 1966, 'director': 142, 'genero': 'Musical', 'cast': [107, 134], 'mejor pelicula': 'no'}, 21: {'año': 1998, 'director': 35, 'genero': 'Aventura', 'cast': [17, 184, 50], 'mejor pelicula': 'no'}, 22: {'año': 1970, 'director': 45, 'genero': 'Drama', 'cast': [], 'mejor pelicula': 'no'}, 23: {'año': 2001, 'director': 74, 'genero': 'Terror', 'cast': [], 'mejor pelicula': 'no'}, 24: {'año': 1973, 'director': 67, 'genero': 'Documental', 'cast': [72, 32], 'mejor pelicula': 'no'}, 25: {'año': 2011, 'director': 115, 'genero': 'Drama', 'cast': [149, 176, 111, 177, 67], 'mejor pelicula': 'no'}, 26: {'año': 2022, 'director': 7, 'genero': 'Documental', 'cast': [], 'mejor pelicula': 'no'}, 27: {'año': 2001, 'director': 196, 'genero': 'Suspense', 'cast': [], 'mejor pelicula': 'no'}, 28: {'año': 1999, 'director': 36, 'genero': 'Ciencia ficción', 'cast': [22], 'mejor pelicula': 'no'}, 29: {'año': 1991, 'director': 50, 'genero': 'Fantasía', 'cast': [145], 'mejor pelicula': 'no'}, 30: {'año': 2019, 'director': 25, 'genero': 'Comedia', 'cast': [37, 57], 'mejor pelicula': 'no'}, 31: {'año': 2017, 'director': 167, 'genero': 'Animación', 'cast': [165, 173], 'mejor pelicula': 'no'}, 32: {'año': 2007, 'director': 199, 'genero': 'Western', 'cast': [111], 'mejor pelicula': 'no'}, 33: {'año': 1981, 'director': 109, 'genero': 'Terror', 'cast': [114], 'mejor pelicula': 'no'}, 34: {'año': 1987, 'director': 193, 'genero': 'Musical', 'cast': [97, 98], 'mejor pelicula': 'no'}, 35: {'año': 1965, 'director': 172, 'genero': 'Acción', 'cast': [106, 150, 173], 'mejor pelicula': 'no'}, 36: {'año': 1992, 'director': 8, 'genero': 'Comedia', 'cast': [159], 'mejor pelicula': 'no'}, 37: {'año': 1984, 'director': 154, 'genero': 'Romance', 'cast': [], 'mejor pelicula': 'no'}, 38: {'año': 2006, 'director': 101, 'genero': 'Acción', 'cast': [133, 155], 'mejor pelicula': 'no'}, 39: {'año': 1988, 'director': 140, 'genero': 'Documental', 'cast': [169, 55], 'mejor pelicula': 'no'}, 40: {'año': 1991, 'director': 175, 'genero': 'Ciencia ficción', 'cast': [120], 'mejor pelicula': 'no'}, 41: {'año': 1978, 'director': 36, 'genero': 'Western', 'cast': [106, 93], 'mejor pelicula ...

# %% [markdown]
# ## Consultas
#
# Escriba aquí las consultas pedidas. Recuerde agregar una descripción _breve_ de cómo funciona la solución. **Escriba las consultas de forma ordenada.**
#
# **NOTA:** Cuando en una consulta diga "X cosa" significa que ustedes deben de elegir ese X por lo que para cualquier otro X debe de funcionar de igual forma.

# %% [markdown]
# ### Consulta 1
# **Nombre de todas las películas publicadas desde el año pasado.**
#
#
# **Ejemplo:**
# |Nombre|
# |------|
# |Dune 2|
# |...|
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */

# %% [markdown]
# ### Consulta 2
# **Nombre y fecha de publicación de todas las películas del género drama que hayan sido publicadas en el año 2023.**
#
#
# **Ejemplo:**
#
# |Nombre     |Fecha de publicación|
# |-----------|--------------------|
# |Oppenheimer|21-7-2023          |
# |...        |...                 |
#
#
# **Solución:** En la solución 2, obtuvimos el nombre y fecha de publicacion de cada pelicula de la "tabla pelicula", si para la película el año de publicación es 2023 y el genero es "Drama", entonces se imprime, en cualquier otro caso se ignora.
#
# **Nota** En nuestro modelo generado al azar no encontramos peliculas que cumplan las condiciones, por lo que para verificar el código, modificamos las condiciones, entregandonos lo correspondiente.

# %%
# %%sql
#
# SELECT nombre  AS "Nombre", fecha_publicacion AS "Fecha de publicación"
# FROM pelicula
# WHERE EXTRACT(YEAR FROM fecha_publicacion) = 2023
# AND genero = 'Drama'
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# 1 rows affected.
# [('La batalla de la revelación', datetime.date(1966, 2, 26))]

# %% [markdown]
# ### Consulta 3
# **Nombres de todos los actores que participaron en una película de género comedia.**
#
#
# **Ejemplo:**
# |Nombre       |
# |-------------|
# |Margot Robbie|
# |...          |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */

# %% [markdown]
# ### Consulta 4
# **Nombre y cantidad de premios ganados por cada género, ordenados de mayor a menor según la cantidad de premios.**
#
#
# **Ejemplo:**
# |Género  |Cantidad de premios|
# |--------|-------------------|
# |Drama   |99                 |
# |Fantasía|29                 |
# |...     |...                |
#
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */

# %% [markdown]
# ### Consulta 5
# **Mostrar peliculas que tengan 2 o mas actores/actrices ordenadas de mayor a menor segun la cantidad de actores/actrices.**
#
#
# **Ejemplo:**
# |Nombre     |Cantidad de actores|
# |-----------|-------------------|
# |Oppenheimer|7                  |
# |Poor Things|4                  |
# |...        |...                |
#
#
# **Solución:** Para la obtención de esta consulta obtvimos el nombre e id_actores de cada pelicula de la tabla "pelicula", este ultimo se contó, usamos la tabla "actor_participa_en_pelicula" para relacionar peliculas con actores. Los resultados los agrupamos por nombre de pelicula. Se imprimen en orden decendiente las peliculas con mas de 2 actores.

# %%
# %%sql
# SELECT p.nombre AS "Nombre", COUNT(ap.id_actor) AS "Cantidad de actores"
# FROM pelicula p
# JOIN actor_participa_en_pelicula ap ON p.id_pelicula = ap.id_pelicula
# GROUP BY p.nombre
# HAVING COUNT(ap.id_actor) >= 2
# ORDER BY "Cantidad de actores" DESC;
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# 138 rows affected.
# [('La escalada de el mago', 7),
#  ('El laberinto de la caverna', 7),
#  ('El vuelo mágico de la guerra', 6),
#  ('El refugio de la muralla', 6),
#  ('El resurgimiento de la promesa', 6),
#  ('La maldición del vampiro de la aventura', 6),
#  ('El ritual de el hechicero', 5),
#  ('El canto de sirena de el volcán', 5),
#  ('El caballero de el misterio', 5),
#  ('La rebelión de el guardián', 5),
#  ('La llegada de la luz', 5),
#  ('La maldición de la selva', 5),
#  ('La maldición de la montaña', 5),
#  ('El viaje de la resistencia', 5),
#  ('La travesía sin retorno de la paz', 4),
#  ('La leyenda perdida de el lamento', 4),
#  ('El renacimiento de el amor', 4),
#  ('El último viaje de el mago', 4),
#  ('El lamento de la batalla', 4),
#  ('El bosque encantado de la tormenta', 4),
#  ('El enigma de la tierra', 4),
#  ('La maldición de la cárcel', 4),
#  ('La conquista de el renacer', 4),
#  ('La tormenta de la fuga', 4),
#  ('El vuelo de la bestia', 4),
#  ('La invasión de el unicornio', 4),
#  ('La maldición del vampiro de el jardín', 4),
#  ('El regreso de la oscuridad', 4),
#  ('El pacto de el enigma', 4),
#  ('La maldición de la oscuridad', 4),
#  ('La travesía del océano de la senda', 4),
#  ('El eclipse de el puente', 3),
#  ('La fortuna de el misterio', 3),
#  ('El prisionero de el atardecer', 3),
#  ('La redención de la oscuridad', 3),
#  ('La travesía sin retorno de la traición', 3),
#  ('La invasión de la aventura', 3),
#  ('La búsqueda del tesoro de la despedida', 3),
#  ('La búsqueda de la leyenda', 3),
#  ('La metamorfosis de la bestia', 3),
#  ('La fuente de el trono', 3),
#  ('El secreto de el río', 3),
#  ('La maldición de la caverna', 3),
#  ('La maldición del vampiro de el destino', 3),
#  ('La resurrección de la puerta', 3),
#  ('La travesía sin retorno de el trono', 3),
#  ('El lamento de la traición', 3),
#  ('El último viaje de el laberinto', 3),
#  ('El último viaje de la aventura', 3),
#  ('El tesoro escondido de el misterio', 3),
#  ('La metamorfosis de la reina', 3),
#  ('El secreto oscuro de el vuelo', 3),
#  ('La sombra de la cueva', 3),
#  ('La profecía de la mariposa', 3),
#  ('El tesoro escondido de el sueño', 3),
#  ('La llegada de la prisión', 3),
#  ('El eclipse de la esperanza', 3),
#  ('La leyenda de la cueva', 3),
#  ('El secreto de la salvación', 3),
#  ('El misterio de la neblina', 3),
#  ('El resurgimiento de el trono', 3),
#  ('El amanecer de el volcán', 3),
#  ('La estirpe de la bruma', 3),
#  ('La estirpe de el secreto', 3),
#  ('El caballero de la sonrisa', 3),
#  ('El misterio de la senda', 3),
#  ('La estrella fugaz de la verdad', 3),
#  ('La rebelión de la senda', 3),
#  ('La maldición de la pesadilla', 3),
#  ('La fuente de el pacto', 3),
#  ('El cuento de hadas de la luz', 3),
#  ('El misterio de el peligro', 2),
#  ('La profecía de la huida', 2),
#  ('La leyenda de la escuela', 2),
#  ('El caballero de la tormenta', 2),
#  ('La redención de el guardián', 2),
#  ('La odisea de la bestia', 2),
#  ('La estrella fugaz de la revelación', 2),
#  ('El castillo de el monstruo', 2),
#  ('El arco iris de la nube', 2),
#  ('La senda de el laberinto', 2),
#  ('El príncipe de el destino', 2),
#  ('La danza macabra de la ciudad', 2),
#  ('La profecía de la estrella fugaz', 2),
#  ('Las aventuras de el guardián', 2),
#  ('La canción de el viajero', 2),
#  ('El espejismo de el desafío', 2),
#  ('El vuelo de la fortuna', 2),
#  ('El laberinto de el misterio', 2),
#  ('El hechizo de la profecía', 2),
#  ('La canción de el amanecer', 2),
#  ('La tormenta de el ángel', 2),
#  ('La profecía de la esperanza', 2),
#  ('El viajero de la esperanza', 2),
#  ('El resurgimiento de el faro', 2),
#  ('El enigma de la expedición', 2),
#  ('La odisea de la cueva', 2),
#  ('La travesía de la pesadilla', 2),
#  ('La fortuna de la verdad', 2),
#  ('El prisionero de la guerra', 2),
#  ('La fuga de el puente', 2),
#  ('El resurgimiento de la fortuna', 2),
#  ('El refugio de la isla', 2),
#  ('El hechizo de la estrella', 2),
#  ('La fuga de la prisión', 2),
#  ('El canto de sirena de el renacimiento', 2),
#  ('El eclipse de la ley', 2),
#  ('La estirpe de la estrella fugaz', 2),
#  ('El canto de sirena de la clave', 2),
#  ('El laberinto de la nube', 2),
#  ('La doncella de la trampa', 2),
#  ('La llegada de el río', 2),
#  ('La danza de la bienvenida', 2),
#  ('El bosque encantado de el ángel', 2),
#  ('El amanecer de la cárcel', 2),
#  ('Las aventuras de el lobo', 2),
#  ('El espejismo de la ciudad', 2),
#  ('El viajero de la libertad', 2),
#  ('La fortuna de el explorador', 2),
#  ('La historia de el sacrificio', 2),
#  ('La llegada de el misterio', 2),
#  ('El resurgimiento de la fuga', 2),
#  ('El eclipse de la profecía', 2),
#  ('La llave de la travesía', 2),
#  ('El prisionero de el lamento', 2),
#  ('El laberinto de el legado', 2),
#  ('El camino hacia la oscuridad', 2),
#  ('La búsqueda del tesoro de la esperanza', 2),
#  ('El prisionero de la sirena', 2),
#  ('La batalla de la magia', 2),
#  ('La fuente de el susurro', 2),
#  ('La venganza de el río', 2),
#  ('El enigma de la selva', 2),
#  ('La maldición de la espada mágica', 2),
#  ('La danza de la tormenta', 2),
#  ('La canción de la resistencia', 2),
#  ('El lamento de el guardián', 2),
#  ('La profecía de el renacimiento', 2)]

# %% [markdown]
# ### Consulta 6
# **Nombre de la película con la mayor brecha de edad entre el actor más joven y el actor más viejo que participen en ella, y las edades de dichos actores.** (Si hay empate, mostrar solamente uno).
#
#
# **Ejemplo:**
# |Nombre|Edad del actor más joven|Edad del actor más viejo|
# |------|------------------------|------------------------|
# |Barbie|16                      |92                      |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */

# %% [markdown]
# ### Consulta 7
# **Año de cada premio ganado por la película de mayor duración.** (Si hay empate, elegir solamente uno).
#
#
# **Ejemplo:**
# |Año |
# |----|
# |2024|
# |... |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */

# %% [markdown]
# ### Consulta 8
# **Nombre de todos los actores que han trabajado con más de un director, la cantidad de directores con las que han trabajado y el nombre de una de las películas.**
#
#
# **Ejemplo:**
# |Nombre del actor|Cantidad de directores|Nombre de una película|
# |----------------|----------------------|----------------------|
# |Cillian Murphy  |29                    |Oppenheimer           |
# |...             |...                   |...                   |
#
#
# **Solución:** Para encontrar los actores que cumplen las condiciones obtuvimos cada actor de la tabla "actor_participa_en_pelicula" que relaciona actores de la tabla "actores" con peliculas de la tabla "pelicula" y contamos la candidad de directores diferentes para cada actor. Agrupamos los datos y si la "id_director" para cada actor es mayor a 1, se imprime. Finalmente se ordenó de manera decreciente.

# %%
# %%sql
# SELECT a.nombre AS "Nombre del actor",
#        COUNT(DISTINCT p.id_director) AS "Cantidad de directores",
#        MIN(p.nombre) AS "Nombre de una pelicula"
# FROM actor_participa_en_pelicula ap
# JOIN actor a ON ap.id_actor = a.id_actor
# JOIN pelicula p ON ap.id_pelicula = p.id_pelicula
# GROUP BY a.id_actor, a.nombre
# HAVING COUNT(DISTINCT p.id_director) > 1
# ORDER BY "Cantidad de directores" DESC;
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# 143 rows affected.
# [('Beatriz Gao', 9, 'El bosque encantado de el ángel'),
#  ('Isa Yamamoto', 7, 'El cuento de hadas de la luz'),
#  ('Han Hidalgo', 6, 'El canto de sirena de el volcán'),
#  ('Theresa Xavier', 6, 'El prisionero de la guerra'),
#  ('Qiu Lopez', 6, 'El camino hacia el enigma'),
#  ('Mikhail Estevez', 6, 'El laberinto de la caverna'),
#  ('Valeria Xu', 6, 'El misterio de el peligro'),
#  ('Yusef Borges', 5, 'El amanecer de la batalla'),
#  ('Quentin Zhang', 5, 'El caballero de el misterio'),
#  ('Nina Urbina', 5, 'El refugio de la muralla'),
#  ('Tatiana Ferreira', 5, 'El canto de sirena de la magia'),
#  ('Nina Montenegro', 5, 'El bosque encantado de la tormenta'),
#  ('Jin Joaquim', 5, 'El bosque encantado de el ángel'),
#  ('Genghis Pacheco', 5, 'El cuento de hadas de la caverna'),
#  ('Isa Kumar', 5, 'El laberinto de la heroína'),
#  ('Yasmin Lopez', 4, 'El amanecer de la cárcel'),
#  ('Wang Kawaguchi', 4, 'El tesoro escondido de el sueño'),
#  ('Javier Ivanov', 4, 'El eclipse de la ley'),
#  ('Omar Ivanov', 4, 'El eclipse de el puente'),
#  ('Giovanni Bianchi', 4, 'El canto de sirena de el renacimiento'),
#  ('Orhan Esteves', 4, 'El cuento de hadas de la luz'),
#  ('Leticia Teles', 4, 'El resurgimiento de la promesa'),
#  ('Patricia Esteves', 4, 'El prisionero de la alianza'),
#  ('Qiu Nguyen', 4, 'El eclipse de el puente'),
#  ('Zoya Lima', 4, 'El eclipse de la esperanza'),
#  ('Akira Urbina', 4, 'La danza macabra de el peligro'),
#  ('Fadhila Hernandez', 4, 'El enigma de la tierra'),
#  ('Tatiana Jimenez', 4, 'El ritual de el hechicero'),
#  ('Abdullah Quintana', 4, 'El resurgimiento de la fuga'),
#  ('Rashid Santana', 4, 'El misterio de la senda'),
#  ('Leonardo Vargas', 4, 'El espejismo de el desafío'),
#  ('Valeria Petrov', 4, 'El enigma de la tierra'),
#  ('Parvati Goncalves', 4, 'El caballero de el misterio'),
#  ('Emiko Janssen', 4, 'El caballero de el misterio'),
#  ('Fabiana Pacheco', 4, 'El caballero de el misterio'),
#  ('Jasmin Uchoa', 4, 'La maldición del vampiro de el jardín'),
#  ('Kamala Velez', 4, 'El príncipe de la corrupción'),
#  ('Hiroko Cruz', 4, 'El lamento de la traición'),
#  ('Rosa Urbina', 4, 'El vuelo de la bestia'),
#  ('Han Rocha', 4, 'El enigma de la selva'),
#  ('Parvati Vargas', 4, 'El caballero de la pesadilla'),
#  ('Mikhail Xu', 4, 'El refugio de la isla'),
#  ('Natalia Rocha', 4, 'El caballero de la sonrisa'),
#  ('Wang Goncalves', 4, 'El hechizo de la guerra'),
#  ('Zafar Queiroz', 4, 'El prisionero de el lamento'),
#  ('Irina Ueno', 4, 'El canto de sirena de el volcán'),
#  ('Abdullah Pacheco', 4, 'El arco iris de la nube'),
#  ('Kamala Pereira', 4, 'El misterio de la senda'),
#  ('Rashid Velez', 4, 'La fuente de el trono'),
#  ('Darius Olivares', 4, 'La fuga de la prisión'),
#  ('Chidike Alvarez', 3, 'El eclipse de la ley'),
#  ('Bianca Olivares', 3, 'El arco iris de el héroe'),
#  ('Hiroko Borges', 3, 'El último viaje de la aventura'),
#  ('Rashid Uchoa', 3, 'El caballero de el misterio'),
#  ('Aarav Vieira', 3, 'El bosque encantado de la tormenta'),
#  ('Jin Olivares', 3, 'El espejismo de el desafío'),
#  ('Fabiana Watanabe', 3, 'La llegada de la luz'),
#  ('Hiroko Zambrano', 3, 'El prisionero de el atardecer'),
#  ('Dmitri Vargas', 3, 'La leyenda perdida de el lamento'),
#  ('Mehmet Rodriguez', 3, 'La maldición de la pesadilla'),
#  ('Aarav Lopes', 3, 'La invasión de el unicornio'),
#  ('Emiko Yilmaz', 3, 'La invasión de la aventura'),
#  ('Bianca Lopez', 3, 'El enigma de la tierra'),
#  ('Zafar Uchoa', 3, 'El despertar de el río'),
#  ('Nadia Borges', 3, 'El camino hacia la oscuridad'),
#  ('Umberto Lima', 3, 'El cuento de hadas de la luz'),
#  ('Alessandro Henriquez', 3, 'El resurgimiento de la promesa'),
#  ('Valentina Yan', 3, 'El vuelo mágico de la guerra'),
#  ('Genghis Vargas', 3, 'El resurgimiento de el abismo'),
#  ('Fatemeh Iglesias', 3, 'El espejismo de la ciudad'),
#  ('Han Santos', 3, 'El camino hacia la oscuridad'),
#  ('Zafar Santos', 3, 'El grito de la caza'),
#  ('Bianca Goncalves', 3, 'El amanecer de el volcán'),
#  ('Zafar Henriquez', 3, 'El hechizo de la estrella'),
#  ('Leonardo Zambrano', 3, 'El guardián de el guardián'),
#  ('Katarina Almeida', 3, 'El laberinto de la nube'),
#  ('Mikhail Zapata', 3, 'La llegada de el río'),
#  ('Giovanni Carvalho', 3, 'La danza de la bienvenida'),
#  ('Ilya Duarte', 3, 'El eclipse de la esperanza'),
#  ('Xavier Olivares', 3, 'El refugio de el caos'),
#  ('Tatiana Tan', 3, 'El vuelo de la fortuna'),
#  ('Kamala Zambrano', 3, 'El caballero de la tormenta'),
#  ('Abdullah Gao', 3, 'El despertar de la pesadilla'),
#  ('Katarina Vieira', 3, 'La invasión de la aventura'),
#  ('Yasmin Barros', 3, 'El hechizo de la salvación'),
#  ('Katarina Rodriguez', 2, 'La maldición de la selva'),
#  ('Oscar Rodriguez', 2, 'El resurgimiento de la fuga'),
#  ('Quintus Duarte', 2, 'La odisea de la bestia'),
#  ('Chiyoko Zapata', 2, 'La maldición de la montaña'),
#  ('Elif Ueno', 2, 'El último viaje de el mago'),
#  ('Yuri Xavier', 2, 'El amanecer de la cárcel'),
#  ('Xin Yilmaz', 2, 'El caballero de la tormenta'),
#  ('Theresa Qian', 2, 'El viajero de el sapo'),
#  ('Wang Zhang', 2, 'La invasión de la cascada'),
#  ('Bianca Teles', 2, 'El resurgimiento de la promesa'),
#  ('Yuri Goncalves', 2, 'La estirpe de la bruma'),
#  ('Emiko Rocha', 2, 'El pacto de el enigma'),
#  ('Parvati Ortega', 2, 'El pacto de el enigma'),
#  ('Salim Bianchi', 2, 'El secreto de el río'),
#  ('Kamala Vieira', 2, 'El vuelo de la fortuna'),
#  ('Han Sousa', 2, 'La estrella fugaz de la verdad'),
#  ('Salim Kawaguchi', 2, 'La canción de el viajero'),
#  ('Umberto Qian', 2, 'El vuelo mágico de la guerra'),
#  ('Xin Rocha', 2, 'El último viaje de el laberinto'),
#  ('Nadia Yamamoto', 2, 'El castillo de el monstruo'),
#  ('Umar Ortega', 2, 'El eclipse de el puente'),
#  ('Pilar Xu', 2, 'El eclipse de la esperanza'),
#  ('Fatemeh Almeida', 2, 'El regreso de la oscuridad'),
#  ('Theresa Santos', 2, 'El laberinto de el legado'),
#  ('Parvati Ivanov', 2, 'La estirpe de la estrella fugaz'),
#  ('Akira Ueno', 2, 'El pacto de el enigma'),
#  ('Leticia Abadi', 2, 'El caballero de la sonrisa'),
#  ('Wilhelmina Inácio', 2, 'El laberinto de la nube'),
#  ('Rashid Hernandez', 2, 'El arco iris de la nube'),
#  ('Chidike Yilmaz', 2, 'El canto de sirena de el volcán'),
#  ('Irina Bianchi', 2, 'El hechizo de la profecía'),
#  ('Jasmin Inácio', 2, 'El lamento de la batalla'),
#  ('Darius Mendes', 2, 'La tormenta de el ángel'),
#  ('Valentina Ortega', 2, 'El grito de la sonrisa'),
#  ('Leonardo Rocha', 2, 'El resurgimiento de la promesa'),
#  ('Xavier Bianchi', 2, 'El canto de sirena de el renacimiento'),
#  ('Qiu Quintana', 2, 'La maldición de la cárcel'),
#  ('Elena Nguyen', 2, 'El viajero de el mar'),
#  ('Khaled Tan', 2, 'El laberinto de la caverna'),
#  ('Yasmin Carvalho', 2, 'El refugio de la muralla'),
#  ('Rashid Rocha', 2, 'La leyenda perdida de el lamento'),
#  ('Isa Duarte', 2, 'El enigma de la selva'),
#  ('Fatemeh Montenegro', 2, 'La conquista de el renacer'),
#  ('Pilar Goncalves', 2, 'La fuente de el pacto'),
#  ('Jin Zhang', 2, 'El bosque encantado de la tormenta'),
#  ('Sakura Oliveira', 2, 'La danza macabra de la ciudad'),
#  ('Umberto Dutta', 2, 'La búsqueda del tesoro de la despedida'),
#  ('Patricia Hidalgo', 2, 'La estrella fugaz de la verdad'),
#  ('Gustavo Almeida', 2, 'El hechizo de la profecía'),
#  ('Samir Qian', 2, 'El descubrimiento de el océano'),
#  ('Javier Ramos', 2, 'La fortuna de el explorador'),
#  ('Yusef Vieira', 2, 'El misterio de la neblina'),
#  ('Leonardo Yan', 2, 'El misterio de el peligro'),
#  ('Ilya Abadi', 2, 'El ritual de el hechicero'),
#  ('Patricia Wu', 2, 'La leyenda de la escuela'),
#  ('Patricia Vargas', 2, 'La estirpe de la estrella fugaz'),
#  ('Yusef Henriquez', 2, 'El canto de sirena de el volcán'),
#  ('Nina Kawaguchi', 2, 'El vuelo de la bestia')]

# %% [markdown]
# ### Consulta 9
#
# **Nombre de todos los actores que han participado sólo en películas dirigidas por el director con id\_director 1.**
#
#
# **Ejemplo:**
# |Nombre      |
# |------------|
# |Ryan Gosling|
# |...         |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */

# %% [markdown]
# ### Consulta BONUS
#
# **Nombre de todos los actores que nunca han ganado un premio, todas las películas en las que han participado y el nombre, número total de películas y número total de premios de los directores de cada película.**
#
#
# **Ejemplo:**
# |Nombre del actor|Nombre de la película|Nombre del director|Número de películas del director|Número de premios del director|
# |----------------|---------------------|-------------------|--------------------------------|-----------------------|
# |Mark Ruffalo    |Poor Things          |Yorgos Lanthimos   |4                               |0                      |
# |Saoirse Ronan   |Lady Bird            |Greta Gerwig       |20                              |1                      |
# |Saoirse Ronan   |Little Women         |Greta Gerwig       |20                              |1                      |
# |...             |...                  |...                |...                             |...                    |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=cafe4e99-499e-4e36-b9fd-48e2d31e0196' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
