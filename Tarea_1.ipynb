# %% [markdown]
# # Tarea 1 Bases de Datos 2024-1 Grupo XX
#
# _Recuerde modificar esta celda y la siguiente! (Borre esta línea también)._

# %% [markdown]
# ## Integrantes:
# * Nombre Integrante 1 - Rol-1
# * Nombre Integrante 2 - Rol-2
# * Nombre Integrante 3 - Rol-3

# %% [markdown]
# ## Requisitos para Correr el Notebook
#
# Para poder utilizar este Notebook se debe tener instalado:
# - **Python 3**
# - **Jupyter**
# - La librería **ipython-sql** (Poder ejecutar sql en Jupyter Notebook)
# - PostgreSQL y su conector desde Python(**psycopg2**)
#
# **IMPORTANTE:** Este Jupyter Notebook se conectará a su servicio de Base de Datos PostgreSQL de manera **local**, por lo que **no funcionará correctamente en el entorno Google Collab.**
#
# Para instalar las dependencias, ejecute (**recuerde actualizar pip3**):

# %%
! pip3 install ipython-sql

! pip3 install psycopg2

# %% [markdown]
# ## Importar dependencias

# %%
import random
from datetime import datetime, timedelta

#Librerías para PostgreSQL
import psycopg2

# %% [markdown]
# Para conectarse a la base de datos, completen los datos relevantes en la variable DATABASE_URL.
#
# * Cambie `user` por el usuario que utilizó en Postgres para acceder a la Base de Datos. Por defecto `postgres`.
# * Cambie `password` por la contraseña de dicho usuario. **Recuerde borrarla antes de entregar su tarea.**
# * Cambie `port` por el puerto en que se ejecuta su servicio de Base de Datos. Por defecto `5432`.
# * Cambie `database` por el nombre de la BD (Schema) que creó en Postgres.
#
# Ejemplo: `postgresql://postgres:pass_segura@localhost:5432/tarea-bd`

# %%
# %reload_ext sql
# %env DATABASE_URL=postgresql://postgres:1234@localhost:5432/tarea1
# Out:
# env: DATABASE_URL=postgresql://postgres:1234@localhost:5432/tarea1

# %% [markdown]
# Para conectarse de forma declarativa a la Base de Datos, utilice el siguiente código:

# %%
#Recuerde cambiar los valores de USER, DBNAME y PASSWORD por los mismos de la celda superior.
conn = psycopg2.connect(
   host="localhost",
   user="postgres",
   dbname='tarea1',
   password="1234",
)

print(conn)
# Out:
# <connection object at 0x00000208D6094F20; dsn: 'user=postgres password=xxx dbname=tarea1 host=localhost', closed: 0>

# %% [markdown]
# ## Crear tablas
#
# Aquí inserta el código SQL que creara las tablas de la base de datos:

# %% [markdown]
# ### Tabla "Director"

# %%
# %%sql
#
# CREATE TABLE director (
#     id_director INTEGER GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45) NOT NULL,
#     edad INT NOT NULL,
#     PRIMARY KEY (id_director)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# Done.
# []

# %% [markdown]
# ### Tabla "Actor"

# %%
# %%sql
# CREATE TABLE actor (
#     id_actor INTEGER GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45) NOT NULL,
#     edad INTEGER NOT NULL,
#     PRIMARY KEY (id_actor)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# Done.
# []

# %% [markdown]
# ### Tabla "Pelicula"

# %%
# %%sql
# CREATE TABLE pelicula (
#     id_pelicula INTEGER GENERATED ALWAYS AS IDENTITY,
#     id_director INTEGER,
#     nombre VARCHAR(45) NOT NULL,
#     genero VARCHAR(45) NOT NULL,
#     duracion INTEGER NOT NULL,
#     fecha_publicacion DATE NOT NULL,
#     PRIMARY KEY (id_pelicula),
#     FOREIGN KEY (id_director) REFERENCES director (id_director)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# Done.
# []

# %% [markdown]
# ### Tabla "actor_participa_en_pelicula"

# %%
# %%sql
# CREATE TABLE actor_participa_en_pelicula (
#     id_actor INTEGER,
#     id_pelicula INTEGER,
#     FOREIGN KEY (id_actor) REFERENCES Actor (id_actor),
#     FOREIGN KEY (id_pelicula) REFERENCES pelicula (id_pelicula)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_director"

# %%
# %%sql
# CREATE TABLE premio_mejor_director (
#     id_premio_dir INTEGER GENERATED ALWAYS AS IDENTITY,
#     id_director INTEGER,
#     PRIMARY KEY (id_premio_dir),
#     FOREIGN KEY (id_director) REFERENCES pelicula (id_pelicula),
#     anio INTEGER NOT NULL
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_actor"

# %%
# %%sql
# CREATE TABLE premio_mejor_actor (
#     id_premio_act INTEGER GENERATED ALWAYS AS IDENTITY,
#     id_actor INTEGER,
#     anio INTEGER NOT NULL,
#     PRIMARY KEY (id_premio_act),
#     FOREIGN KEY (id_actor) REFERENCES actor (id_actor)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# Done.
# []

# %% [markdown]
# ### Tabla  "Premio_mejor_pelicula"

# %%
# %%sql
# CREATE TABLE premio_mejor_pelicula (
#     id_premio_pel INTEGER GENERATED ALWAYS AS IDENTITY,
#     id_pelicula INTEGER,
#     anio INTEGER NOT NULL,
#     PRIMARY KEY (id_premio_pel),
#     FOREIGN KEY (id_pelicula) REFERENCES pelicula (id_pelicula)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# Done.
# []

# %% [markdown]
# ## Código Generador de Datos
#
# Ejecute este código para cargar datos a las tablas creadas.

# %%
import random
from datetime import date
#Prefijos y sufijos para crear nombres de peliculas aleatoriamente
prefijos = ["El misterio de", "El viaje de", "Las aventuras de", "La historia de", "El secreto de", "La leyenda de", "La búsqueda de", "El regreso de", "El tesoro de", "La odisea de", "La misión de", "La conquista de", "La travesía de", "El destino de", "El despertar de", "El último viaje de", "La venganza de", "El renacimiento de", "La rebelión de", "El vuelo de", "El descubrimiento de", "La sombra de", "La redención de", "El ritual de", "La batalla de", "El hechizo de", "El pacto de", "La profecía de", "El laberinto de", "El prisionero de", "La llegada de", "El amanecer de", "La fortuna de", "El enigma de", "La invasión de", "El resurgimiento de", "La metamorfosis de", "El eclipse de", "La danza de", "La canción de", "El lamento de", "La trampa de", "La travesura de", "El tesoro escondido de", "El vuelo mágico de", "El canto de sirena de", "El bosque encantado de", "La maldición de", "La leyenda perdida de", "La tormenta de", "El camino hacia", "El viajero de", "El guardián de", "La cripta de", "El espejismo de", "El secreto oscuro de", "La resurrección de", "La danza macabra de", "La fuga de", "La estrella fugaz de", "El grito de", "El castillo de", "La travesía sin retorno de", "La estirpe de", "La llave de", "El cuento de hadas de", "El príncipe de", "La doncella de", "El arco iris de", "La fuente de", "El refugio de", "La senda de", "La búsqueda del tesoro de", "El caballero de", "La escalada de", "La maldición del vampiro de", "La travesía del océano de"]
sufijos = ["el león", "la bailarina", "el sapo", "la estrella", "el mago", "la princesa", "el guerrero", "la criatura", "el explorador", "la bruja", "la montaña", "la isla", "el dragón", "la cueva", "el lobo", "la reina", "el rey", "la espada", "el castillo", "la flor", "la selva", "el tesoro", "la nube", "el unicornio", "la sirena", "el volcán", "la neblina", "la cascada", "el árbol", "la ciudad", "el río", "la tormenta", "la luna", "el sol", "la estrella fugaz", "el camino", "la sombra", "el laberinto", "la ola", "la caverna", "el mar", "el ángel", "la espada mágica", "el destino", "el faro", "el puente", "el horizonte", "el valle", "el puente", "la muralla", "el bosque", "la gruta", "la corona", "la aldea", "la batalla", "la noche", "el amanecer", "el atardecer", "el sueño", "la pesadilla", "el héroe", "la heroína", "la aventura", "el misterio", "la magia", "la leyenda", "la profecía", "el secreto", "el desafío", "la trampa", "la mariposa", "el jardín", "la tormenta", "la montaña", "el río", "el rincón", "el guardián", "el hechizo", "la misión", "la expedición", "la caza", "el trono", "la batalla", "la aventura", "el legado", "el enigma", "la clave", "el guardián", "el viajero", "la cripta", "el laberinto", "el abismo", "el muro", "la senda", "el laberinto", "la bruma", "la travesía", "el vuelo", "la sirena", "el hechicero", "la escuela", "la academia", "la sombra", "la estrella", "el ángel", "la gárgola", "la profecía", "la puerta", "la guerra", "el pacto", "la ley", "el viaje", "la huida", "la fortuna", "la prisión", "la cárcel", "el lamento", "la sonrisa", "el susurro", "el grito", "la fuga", "el monstruo", "la bestia", "la maraña", "el sueño", "la pesadilla", "la verdad", "el mito", "el océano", "la estrella", "el fuego", "la tierra", "el cielo", "la oscuridad", "la luz", "el caos", "la esperanza", "la promesa", "la traición", "el destino", "la salvación", "la perdición", "la soledad", "la compañía", "la amistad", "el amor", "la pasión", "la venganza", "el perdón", "el renacer", "el adiós", "la bienvenida", "la despedida", "el encuentro", "la desgracia", "la fortuna", "la guerra", "la paz", "la caída", "el renacimiento", "la resistencia", "el sacrificio", "la alianza", "el viaje", "el descubrimiento", "la revelación", "la esperanza", "la batalla", "el peligro", "la aventura", "la magia", "la pesadilla", "el misterio", "la leyenda", "la guerra", "el amor", "la traición", "la redención", "la libertad", "la prisión", "la oscuridad", "la luz", "la corrupción"]
#Nombres y apellidos para crear nombres de peliculas aleatoriamente
nombres = ["Akira", "Alessandro", "Chen", "Darius", "Emiko", "Fatemeh", "Gustavo", "Hiroko", "Isa", "Jin", "Katarina", "Lakshmi", "Mikhail", "Nina", "Omar", "Pilar", "Qiu", "Rashid", "Sakura", "Tatiana", "Umar", "Valentina", "Wang", "Xavier", "Yasmin", "Zafar", "Aarav", "Beatriz", "Chidike", "Darya", "Elif", "Fadhila", "Giovanni", "Hanako", "Ilya", "Jasmin", "Khaled", "Leticia", "Mehmet", "Nadia", "Orhan", "Parvati", "Quintus", "Rania", "Salim", "Theresa", "Ursula", "Vivek", "Wilhelmina", "Xin", "Yusef", "Zoya", "Abdullah", "Bianca", "Chiyoko", "Dmitri", "Elena", "Fabiana", "Genghis", "Han", "Irina", "Javier", "Kamala", "Leonardo", "Mina", "Natalia", "Oscar", "Patricia", "Quentin", "Rosa", "Samir", "Tatjana", "Umberto", "Valeria", "Wan", "Ximena", "Yuri", "Zara"]
apellidos = ["Abadi", "Bianchi", "Cruz", "Dutta", "Etxebarria", "Ferreira", "Gao", "Hernandez", "Ivanov", "Janssen", "Kawaguchi", "Lopez", "Montenegro", "Nguyen", "Olivares", "Petrov", "Qian", "Rodriguez", "Santos", "Tan", "Ueno", "Vargas", "Wu", "Xia", "Yilmaz", "Zhang", "Almeida", "Borges", "Carvalho", "Diniz", "Esteves", "Fernandes", "Gomes", "Henriquez", "Inácio", "Joaquim", "Lima", "Mendes", "Nogueira", "Oliveira", "Pereira", "Quintana", "Ramos", "Santana", "Teixeira", "Uchoa", "Vieira", "Xavier", "Yamamoto", "Zambrano", "Alvarez", "Barros", "Correia", "Duarte", "Estevez", "Figueiredo", "Goncalves", "Hidalgo", "Iglesias", "Jimenez", "Kumar", "Lopes", "Martinez", "Nunes", "Ortega", "Pacheco", "Queiroz", "Rocha", "Sousa", "Teles", "Urbina", "Velez", "Watanabe", "Xu", "Yan", "Zapata"]
# Definir el rango de fechas
fecha_inicial = datetime(1960, 1, 1)
fecha_final = datetime(2023, 12, 31)

# Calcular la diferencia entre las fechas inicial y final
diferencia = fecha_final - fecha_inicial

# Generar una fecha aleatoria dentro del rango
fecha_aleatoria = fecha_inicial + timedelta(days=random.randint(0, diferencia.days))

# Convertir la fecha al formato SQL DATE (YYYY-MM-DD)
fecha_sql = fecha_aleatoria.strftime('%Y-%m-%d')

cursor = conn.cursor()

premios_info = {}
directores_ids = []
for _ in range(200):
    nombre = random.choice(nombres) + " " + random.choice(apellidos)
    edad = random.randint(30,90)
    cursor.execute("INSERT INTO director (nombre, edad) VALUES (%s, %s) RETURNING id_director", (nombre, edad))
    id_director = cursor.fetchone()[0]
    directores_ids.append(id_director)
    
actores_ids = []
for _ in range(200):
    nombre = random.choice(nombres) + " " + random.choice(apellidos)
    edad = random.randint(15,70) 
    cursor.execute("INSERT INTO actor (nombre, edad) VALUES (%s, %s) RETURNING id_actor", (nombre, edad))
    id_actor = cursor.fetchone()[0]
    actores_ids.append(id_actor)

peliculas_ids = []
for _ in range(300):
    director_pelicula = random.choice(directores_ids)
    nombre = random.choice(prefijos) + " " + random.choice(sufijos)
    genero = random.choice(["Acción", "Aventura", "Animación", "Comedia", "Documental", "Drama", "Fantasía", "Terror", "Ciencia ficción", "Musical", "Misterio", "Romance", "Suspense", "Western"])
    duracion = random.randint(70,150)
    fecha_aleatoria = fecha_inicial + timedelta(days=random.randint(0, diferencia.days))
    # Convertir la fecha al formato SQL DATE (YYYY-MM-DD)
    fecha_sql = fecha_aleatoria.strftime('%Y-%m-%d')
    cursor.execute("INSERT INTO pelicula (id_director, nombre, genero, duracion, fecha_publicacion) VALUES (%s,%s,%s,%s,%s) RETURNING id_pelicula",(director_pelicula,nombre,genero,duracion,fecha_sql))
    id_pelicula = cursor.fetchone()[0]
    peliculas_ids.append(id_pelicula)
    if id_pelicula not in premios_info:
        premios_info[id_pelicula] = {}
        premios_info[id_pelicula]["año"] = fecha_aleatoria.year
        premios_info[id_pelicula]["director"] = director_pelicula
        premios_info[id_pelicula]["genero"] = genero
        premios_info[id_pelicula]["cast"] = []
        premios_info[id_pelicula]["mejor pelicula"] = "no"
    
lista_pelicula_actor = []
peliculas_actores = {}
for _ in range(500):
    peliculaID = random.choice(peliculas_ids)
    actorID = random.choice(actores_ids)
    if not (peliculaID, actorID) in lista_pelicula_actor:
        cursor.execute("INSERT INTO actor_participa_en_pelicula (id_pelicula, id_actor) VALUES (%s,%s)",(peliculaID,actorID))
        lista_pelicula_actor.append((peliculaID,actorID))
    else:
        continue


for pelicula, actor in lista_pelicula_actor:
    if pelicula in premios_info:
        premios_info[pelicula]["cast"].append(actor)

print(premios_info)
for _ in range(100):
    pelicula_al_azar = random.randint(1,300)
    tipo_de_premio = ["mejor pelicula", "mejor actor", "mejor director"]
    eleccion_premio = random.choice(tipo_de_premio)
    if eleccion_premio == "mejor director":
        if premios_info[pelicula_al_azar]["director"] != "elegido":
            director = premios_info[pelicula_al_azar]["director"]
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_director (id_director, anio) VALUES (%s,%s)",(director, año))
            premios_info[pelicula_al_azar]["director"] = "elegido"
        else:
            continue
    elif eleccion_premio == "mejor actor":
        if premios_info[pelicula_al_azar]["cast"] != []:
            actor = random.choice(premios_info[pelicula_al_azar]["cast"])
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_actor (id_actor, anio) VALUES (%s,%s)",(actor, año))
            premios_info[pelicula_al_azar]["cast"].remove(actor)
        else:
            continue
    elif eleccion_premio == "mejor pelicula":
        if premios_info[pelicula_al_azar]["mejor pelicula"] != "si":
            pelicula = pelicula_al_azar
            año = premios_info[pelicula_al_azar]["año"]
            cursor.execute("INSERT INTO premio_mejor_pelicula (id_pelicula, anio) VALUES (%s,%s)",(pelicula, año))
            premios_info[pelicula_al_azar]["mejor pelicula"] = "si"
        else:
            continue

conn.commit()
cursor.close()
conn.close()
# Out:
# {1: {'año': 2003, 'director': 1, 'genero': 'Comedia', 'cast': [58, 23, 85], 'mejor pelicula': 'no'}, 2: {'año': 1994, 'director': 79, 'genero': 'Acción', 'cast': [77], 'mejor pelicula': 'no'}, 3: {'año': 2013, 'director': 11, 'genero': 'Aventura', 'cast': [146], 'mejor pelicula': 'no'}, 4: {'año': 1997, 'director': 151, 'genero': 'Misterio', 'cast': [131, 24, 23, 8, 121, 175], 'mejor pelicula': 'no'}, 5: {'año': 2013, 'director': 70, 'genero': 'Musical', 'cast': [], 'mejor pelicula': 'no'}, 6: {'año': 2010, 'director': 143, 'genero': 'Fantasía', 'cast': [103, 92, 46], 'mejor pelicula': 'no'}, 7: {'año': 2019, 'director': 90, 'genero': 'Comedia', 'cast': [169], 'mejor pelicula': 'no'}, 8: {'año': 1960, 'director': 57, 'genero': 'Misterio', 'cast': [91], 'mejor pelicula': 'no'}, 9: {'año': 1977, 'director': 179, 'genero': 'Misterio', 'cast': [106], 'mejor pelicula': 'no'}, 10: {'año': 2011, 'director': 66, 'genero': 'Western', 'cast': [123], 'mejor pelicula': 'no'}, 11: {'año': 1984, 'director': 184, 'genero': 'Romance', 'cast': [131, 90], 'mejor pelicula': 'no'}, 12: {'año': 2006, 'director': 156, 'genero': 'Aventura', 'cast': [], 'mejor pelicula': 'no'}, 13: {'año': 2005, 'director': 189, 'genero': 'Fantasía', 'cast': [75, 152, 160, 162, 74], 'mejor pelicula': 'no'}, 14: {'año': 1984, 'director': 194, 'genero': 'Animación', 'cast': [168, 91], 'mejor pelicula': 'no'}, 15: {'año': 2021, 'director': 100, 'genero': 'Misterio', 'cast': [], 'mejor pelicula': 'no'}, 16: {'año': 1982, 'director': 135, 'genero': 'Terror', 'cast': [74], 'mejor pelicula': 'no'}, 17: {'año': 1974, 'director': 8, 'genero': 'Aventura', 'cast': [200, 168], 'mejor pelicula': 'no'}, 18: {'año': 2003, 'director': 165, 'genero': 'Documental', 'cast': [191, 14], 'mejor pelicula': 'no'}, 19: {'año': 2018, 'director': 192, 'genero': 'Comedia', 'cast': [], 'mejor pelicula': 'no'}, 20: {'año': 1980, 'director': 11, 'genero': 'Drama', 'cast': [100, 159], 'mejor pelicula': 'no'}, 21: {'año': 2009, 'director': 16, 'genero': 'Comedia', 'cast': [164], 'mejor pelicula': 'no'}, 22: {'año': 1977, 'director': 60, 'genero': 'Musical', 'cast': [121, 67], 'mejor pelicula': 'no'}, 23: {'año': 1981, 'director': 154, 'genero': 'Terror', 'cast': [4], 'mejor pelicula': 'no'}, 24: {'año': 1961, 'director': 25, 'genero': 'Animación', 'cast': [44, 103, 187], 'mejor pelicula': 'no'}, 25: {'año': 1988, 'director': 89, 'genero': 'Musical', 'cast': [140, 111, 104], 'mejor pelicula': 'no'}, 26: {'año': 1993, 'director': 148, 'genero': 'Acción', 'cast': [90, 78, 37], 'mejor pelicula': 'no'}, 27: {'año': 2002, 'director': 156, 'genero': 'Terror', 'cast': [], 'mejor pelicula': 'no'}, 28: {'año': 2017, 'director': 165, 'genero': 'Acción', 'cast': [192, 5, 179], 'mejor pelicula': 'no'}, 29: {'año': 1964, 'director': 141, 'genero': 'Fantasía', 'cast': [1, 188, 123], 'mejor pelicula': 'no'}, 30: {'año': 2010, 'director': 133, 'genero': 'Suspense', 'cast': [159], 'mejor pelicula': 'no'}, 31: {'año': 1992, 'director': 40, 'genero': 'Aventura', 'cast': [35, 120, 43, 124], 'mejor pelicula': 'no'}, 32: {'año': 1997, 'director': 3, 'genero': 'Drama', 'cast': [41], 'mejor pelicula': 'no'}, 33: {'año': 1993, 'director': 76, 'genero': 'Comedia', 'cast': [139], 'mejor pelicula': 'no'}, 34: {'año': 1995, 'director': 131, 'genero': 'Terror', 'cast': [], 'mejor pelicula': 'no'}, 35: {'año': 2015, 'director': 103, 'genero': 'Romance', 'cast': [], 'mejor pelicula': 'no'}, 36: {'año': 2017, 'director': 110, 'genero': 'Romance', 'cast': [1], 'mejor pelicula': 'no'}, 37: {'año': 2021, 'director': 179, 'genero': 'Western', 'cast': [], 'mejor pelicula': 'no'}, 38: {'año': 1961, 'director': 110, 'genero': 'Drama', 'cast': [62], 'mejor pelicula': 'no'}, 39: {'año': 1963, 'director': 126, 'genero': 'Western', 'cast': [95, 94], 'mejor pelicula': 'no'}, 40: {'año': 1975, 'director': 37, 'genero': 'Romance', 'cast': [58, 178], 'mejor pelicula': 'no'}, 41: {'año': 2021, 'director': 56, 'genero': 'Romance', 'cast': [13], 'mej ...

# %% [markdown]
# ## Consultas
#
# Escriba aquí las consultas pedidas. Recuerde agregar una descripción _breve_ de cómo funciona la solución. **Escriba las consultas de forma ordenada.**
#
# **NOTA:** Cuando en una consulta diga "X cosa" significa que ustedes deben de elegir ese X por lo que para cualquier otro X debe de funcionar de igual forma.

# %% [markdown]
# ### Consulta 1
# **Nombre de todas las películas publicadas desde el año pasado.**
#
#
# **Ejemplo:**
# |Nombre|
# |------|
# |Dune 2|
# |...|
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */

# %% [markdown]
# ### Consulta 2
# **Nombre y fecha de publicación de todas las películas del género drama que hayan sido publicadas en el año 2023.**
#
#
# **Ejemplo:**
#
# |Nombre     |Fecha de publicación|
# |-----------|--------------------|
# |Oppenheimer|21-7-2023          |
# |...        |...                 |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
#
# SELECT nombre, fecha_publicacion, genero
# FROM pelicula
# WHERE EXTRACT(YEAR FROM fecha_publicacion) = 2023
# AND genero = 'Drama'
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# 0 rows affected.
# []

# %% [markdown]
# ### Consulta 3
# **Nombres de todos los actores que participaron en una película de género comedia.**
#
#
# **Ejemplo:**
# |Nombre       |
# |-------------|
# |Margot Robbie|
# |...          |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */

# %% [markdown]
# ### Consulta 4
# **Nombre y cantidad de premios ganados por cada género, ordenados de mayor a menor según la cantidad de premios.**
#
#
# **Ejemplo:**
# |Género  |Cantidad de premios|
# |--------|-------------------|
# |Drama   |99                 |
# |Fantasía|29                 |
# |...     |...                |
#
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */

# %% [markdown]
# ### Consulta 5
# **Mostrar peliculas que tengan 2 o mas actores/actrices ordenadas de mayor a menor segun la cantidad de actores/actrices.**
#
#
# **Ejemplo:**
# |Nombre     |Cantidad de actores|
# |-----------|-------------------|
# |Oppenheimer|7                  |
# |Poor Things|4                  |
# |...        |...                |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT p.id_pelicula, p.nombre AS nombre_pelicula, COUNT(ap.id_actor) AS cantidad_actores
# FROM pelicula p
# JOIN actor_participa_en_pelicula ap ON p.id_pelicula = ap.id_pelicula
# GROUP BY p.id_pelicula, p.nombre
# HAVING COUNT(ap.id_actor) >= 2
# ORDER BY cantidad_actores DESC;
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# 142 rows affected.
# [(4, 'La danza macabra de la misión', 6),
#  (290, 'La danza macabra de la ciudad', 6),
#  (277, 'La danza de la pasión', 6),
#  (110, 'La llegada de la escuela', 6),
#  (69, 'La fuga de la redención', 5),
#  (201, 'La doncella de la escuela', 5),
#  (95, 'La estirpe de la fuga', 5),
#  (230, 'El arco iris de la batalla', 5),
#  (102, 'El vuelo de la sombra', 5),
#  (210, 'El eclipse de la reina', 5),
#  (58, 'La leyenda perdida de la selva', 5),
#  (13, 'El secreto de la gárgola', 5),
#  (96, 'El despertar de el león', 5),
#  (209, 'La leyenda de el susurro', 5),
#  (163, 'El hechizo de la aldea', 4),
#  (144, 'El prisionero de el caos', 4),
#  (236, 'El castillo de el puente', 4),
#  (212, 'El viajero de el atardecer', 4),
#  (281, 'La canción de la expedición', 4),
#  (149, 'La estrella fugaz de la luz', 4),
#  (147, 'La fortuna de el muro', 4),
#  (31, 'La leyenda perdida de el río', 4),
#  (141, 'La conquista de la cascada', 4),
#  (42, 'La doncella de la puerta', 4),
#  (84, 'El enigma de el hechizo', 4),
#  (267, 'La conquista de el bosque', 4),
#  (298, 'La travesía del océano de la sirena', 4),
#  (270, 'La batalla de la caverna', 3),
#  (116, 'El destino de la promesa', 3),
#  (261, 'El viajero de la maraña', 3),
#  (239, 'El vuelo de la tormenta', 3),
#  (291, 'La fuente de la corrupción', 3),
#  (226, 'La travesía del océano de la academia', 3),
#  (61, 'La redención de el camino', 3),
#  (244, 'El lamento de el guerrero', 3),
#  (204, 'La tormenta de la magia', 3),
#  (91, 'La profecía de la selva', 3),
#  (179, 'El ritual de la puerta', 3),
#  (29, 'El resurgimiento de el rincón', 3),
#  (105, 'La doncella de la traición', 3),
#  (6, 'El guardián de la isla', 3),
#  (107, 'El tesoro de el abismo', 3),
#  (93, 'La leyenda perdida de la estrella fugaz', 3),
#  (89, 'El arco iris de la ciudad', 3),
#  (47, 'El viajero de la despedida', 3),
#  (182, 'El tesoro escondido de la guerra', 3),
#  (1, 'El camino hacia el fuego', 3),
#  (178, 'El laberinto de la traición', 3),
#  (145, 'La profecía de el río', 3),
#  (203, 'La llegada de la revelación', 3),
#  (228, 'El eclipse de la maraña', 3),
#  (294, 'El camino hacia la sombra', 3),
#  (71, 'El renacimiento de el vuelo', 3),
#  (132, 'La rebelión de el grito', 3),
#  (115, 'El arco iris de el laberinto', 3),
#  (98, 'La travesía de la bruma', 3),
#  (279, 'La danza de el árbol', 3),
#  (202, 'El prisionero de la sonrisa', 3),
#  (26, 'El renacimiento de el guerrero', 3),
#  (172, 'El hechizo de el puente', 3),
#  (288, 'El bosque encantado de el desafío', 3),
#  (28, 'La danza macabra de el rey', 3),
#  (249, 'La metamorfosis de la fuga', 3),
#  (67, 'La resurrección de el mago', 3),
#  (284, 'El príncipe de la selva', 3),
#  (207, 'La búsqueda de la magia', 3),
#  (224, 'El misterio de el laberinto', 3),
#  (183, 'La tormenta de el monstruo', 3),
#  (150, 'La leyenda perdida de el amor', 3),
#  (248, 'El misterio de la guerra', 3),
#  (24, 'El camino hacia el trono', 3),
#  (25, 'La batalla de la amistad', 3),
#  (94, 'El ritual de el lamento', 3),
#  (256, 'El arco iris de el explorador', 3),
#  (237, 'El renacimiento de el renacimiento', 2),
#  (40, 'La canción de la traición', 2),
#  (234, 'La resurrección de el abismo', 2),
#  (97, 'La odisea de la esperanza', 2),
#  (108, 'La escalada de el explorador', 2),
#  (65, 'El descubrimiento de el lobo', 2),
#  (127, 'El prisionero de la pesadilla', 2),
#  (124, 'La cripta de el lamento', 2),
#  (157, 'El destino de el guardián', 2),
#  (200, 'El regreso de la muralla', 2),
#  (11, 'La venganza de la heroína', 2),
#  (119, 'La cripta de la guerra', 2),
#  (286, 'El descubrimiento de la corrupción', 2),
#  (211, 'La sombra de la luz', 2),
#  (103, 'La metamorfosis de la pesadilla', 2),
#  (136, 'El eclipse de la clave', 2),
#  (184, 'El último viaje de la luz', 2),
#  (72, 'El tesoro escondido de el laberinto', 2),
#  (156, 'El pacto de la estrella', 2),
#  (22, 'La leyenda perdida de la fuga', 2),
#  (259, 'El refugio de la magia', 2),
#  (137, 'La senda de la escuela', 2),
#  (185, 'El laberinto de el puente', 2),
#  (17, 'El espejismo de el lamento', 2),
#  (64, 'La travesía del océano de el descubrimiento', 2),
#  (263, 'El castillo de la sombra', 2),
#  (215, 'La travesía sin retorno de la muralla', 2),
#  (255, 'El regreso de el abismo', 2),
#  (296, 'La trampa de el adiós', 2),
#  (271, 'El hechizo de la luz', 2),
#  (74, 'La batalla de la resistencia', 2),
#  (225, 'El grito de la sirena', 2),
#  (83, 'La resurrección de la guerra', 2),
#  (130, 'El refugio de el descubrimiento', 2),
#  (295, 'La profecía de la princesa', 2),
#  (134, 'El bosque encantado de la bestia', 2),
#  (92, 'El descubrimiento de la prisión', 2),
#  (39, 'La historia de la caída', 2),
#  (219, 'El príncipe de la pesadilla', 2),
#  (252, 'La leyenda perdida de el rincón', 2),
#  (175, 'La maldición de el encuentro', 2),
#  (86, 'El guardián de el árbol', 2),
#  (14, 'Las aventuras de la luz', 2),
#  (297, 'El refugio de el encuentro', 2),
#  (246, 'La estrella fugaz de la montaña', 2),
#  (128, 'La invasión de la venganza', 2),
#  (54, 'El enigma de el tesoro', 2),
#  (78, 'El descubrimiento de la esperanza', 2),
#  (278, 'El tesoro de el renacimiento', 2),
#  (20, 'El despertar de la sirena', 2),
#  (287, 'La fuente de el faro', 2),
#  (272, 'La misión de la gruta', 2),
#  (18, 'El refugio de la libertad', 2),
#  (81, 'La escalada de la traición', 2),
#  (51, 'La fortuna de el mito', 2),
#  (273, 'El amanecer de el puente', 2),
#  (129, 'La canción de la corrupción', 2),
#  (118, 'La danza macabra de el sacrificio', 2),
#  (187, 'El prisionero de el puente', 2),
#  (87, 'El secreto oscuro de el adiós', 2),
#  (154, 'El lamento de el guerrero', 2),
#  (62, 'La historia de el amor', 2),
#  (68, 'La maldición del vampiro de el rincón', 2),
#  (125, 'El enigma de la noche', 2),
#  (52, 'El vuelo mágico de la soledad', 2),
#  (123, 'El grito de la tormenta', 2),
#  (113, 'La cripta de el adiós', 2),
#  (276, 'El secreto oscuro de la pesadilla', 2)]

# %% [markdown]
# ### Consulta 6
# **Nombre de la película con la mayor brecha de edad entre el actor más joven y el actor más viejo que participen en ella, y las edades de dichos actores.** (Si hay empate, mostrar solamente uno).
#
#
# **Ejemplo:**
# |Nombre|Edad del actor más joven|Edad del actor más viejo|
# |------|------------------------|------------------------|
# |Barbie|16                      |92                      |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */

# %% [markdown]
# ### Consulta 7
# **Año de cada premio ganado por la película de mayor duración.** (Si hay empate, elegir solamente uno).
#
#
# **Ejemplo:**
# |Año |
# |----|
# |2024|
# |... |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */

# %% [markdown]
# ### Consulta 8
# **Nombre de todos los actores que han trabajado con más de un director, la cantidad de directores con las que han trabajado y el nombre de una de las películas.**
#
#
# **Ejemplo:**
# |Nombre del actor|Cantidad de directores|Nombre de una película|
# |----------------|----------------------|----------------------|
# |Cillian Murphy  |29                    |Oppenheimer           |
# |...             |...                   |...                   |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT a.nombre AS "Nombre del actor",
#        COUNT(DISTINCT p.id_director) AS "Cantidad de directores",
#        MIN(p.nombre) AS "Nombre de una pelicula"
# FROM actor_participa_en_pelicula ap
# JOIN actor a ON ap.id_actor = a.id_actor
# JOIN pelicula p ON ap.id_pelicula = p.id_pelicula
# GROUP BY a.id_actor, a.nombre
# HAVING COUNT(DISTINCT p.id_director) > 1;
# Out:
#  * postgresql://postgres:***@localhost:5432/tarea1
# 141 rows affected.
# [('Chidike Nogueira', 4, 'El hechizo de el puente'),
#  ('Kamala Jimenez', 3, 'El arco iris de la ciudad'),
#  ('Alessandro Montenegro', 3, 'La danza macabra de la ciudad'),
#  ('Nadia Qian', 3, 'El enigma de el hechizo'),
#  ('Genghis Pereira', 5, 'El arco iris de la ciudad'),
#  ('Rashid Alvarez', 4, 'El príncipe de la pesadilla'),
#  ('Darya Gao', 2, 'La danza de la pasión'),
#  ('Parvati Gao', 4, 'La canción de la expedición'),
#  ('Nina Petrov', 2, 'El descubrimiento de la prisión'),
#  ('Katarina Fernandes', 2, 'La conquista de la cascada'),
#  ('Mehmet Fernandes', 2, 'El laberinto de el puente'),
#  ('Alessandro Ortega', 3, 'El refugio de la libertad'),
#  ('Tatiana Zambrano', 4, 'El renacimiento de el vuelo'),
#  ('Xin Zapata', 2, 'El refugio de la selva'),
#  ('Irina Olivares', 3, 'El laberinto de la traición'),
#  ('Xin Petrov', 2, 'La fuga de el viajero'),
#  ('Fadhila Xia', 2, 'La travesía de la bruma'),
#  ('Fadhila Borges', 2, 'El despertar de la neblina'),
#  ('Chiyoko Alvarez', 3, 'El descubrimiento de la prisión'),
#  ('Pilar Uchoa', 4, 'El camino hacia el fuego'),
#  ('Omar Etxebarria', 3, 'La cripta de el lamento'),
#  ('Tatiana Yilmaz', 3, 'El último viaje de la luz'),
#  ('Theresa Ferreira', 3, 'El enigma de el misterio'),
#  ('Omar Olivares', 4, 'El canto de sirena de la esperanza'),
#  ('Darya Henriquez', 5, 'El arco iris de el laberinto'),
#  ('Ilya Jimenez', 3, 'La búsqueda de el hechicero'),
#  ('Oscar Nogueira', 2, 'La doncella de la traición'),
#  ('Leonardo Santos', 2, 'El refugio de la magia'),
#  ('Abdullah Quintana', 2, 'El eclipse de la maraña'),
#  ('Fabiana Kawaguchi', 4, 'El ritual de el lamento'),
#  ('Wilhelmina Ramos', 3, 'La canción de la expedición'),
#  ('Chidike Ramos', 2, 'El camino hacia el trono'),
#  ('Javier Correia', 2, 'El guardián de la isla'),
#  ('Dmitri Petrov', 5, 'El amanecer de el puente'),
#  ('Oscar Nunes', 2, 'El hechizo de la aldea'),
#  ('Sakura Sousa', 3, 'El arco iris de la batalla'),
#  ('Abdullah Yilmaz', 3, 'El eclipse de la clave'),
#  ('Salim Nunes', 2, 'El ritual de la puerta'),
#  ('Chen Mendes', 2, 'El misterio de la guerra'),
#  ('Hiroko Bianchi', 2, 'El viajero de el atardecer'),
#  ('Mikhail Olivares', 5, 'El lamento de el guerrero'),
#  ('Omar Abadi', 3, 'El caballero de el horizonte'),
#  ('Quentin Zambrano', 4, 'El camino hacia el fuego'),
#  ('Hiroko Zhang', 2, 'El enigma de el hechizo'),
#  ('Giovanni Gomes', 5, 'El grito de la tormenta'),
#  ('Han Wu', 2, 'El enigma de el hechizo'),
#  ('Gustavo Vargas', 3, 'El castillo de el puente'),
#  ('Wilhelmina Xu', 3, 'El castillo de el puente'),
#  ('Abdullah Nogueira', 4, 'El descubrimiento de la esperanza'),
#  ('Dmitri Teles', 3, 'El arco iris de la batalla'),
#  ('Quintus Rocha', 2, 'El camino hacia la sombra'),
#  ('Kamala Duarte', 2, 'El secreto oscuro de la pesadilla'),
#  ('Wang Correia', 3, 'El despertar de el león'),
#  ('Rania Barros', 2, 'El viaje de la aldea'),
#  ('Gustavo Wu', 3, 'El eclipse de la reina'),
#  ('Valentina Duarte', 4, 'El eclipse de la reina'),
#  ('Yuri Barros', 3, 'El secreto de la gárgola'),
#  ('Aarav Iglesias', 2, 'La danza de el árbol'),
#  ('Chiyoko Qian', 6, 'El castillo de la criatura'),
#  ('Umberto Olivares', 4, 'El hechizo de la aldea'),
#  ('Kamala Teles', 2, 'La danza macabra de el sacrificio'),
#  ('Vivek Ueno', 5, 'El hechizo de el puente'),
#  ('Salim Etxebarria', 3, 'El camino hacia la sombra'),
#  ('Ursula Velez', 4, 'El laberinto de el puente'),
#  ('Valeria Nguyen', 7, 'El arco iris de el laberinto'),
#  ('Emiko Almeida', 4, 'El camino hacia el fuego'),
#  ('Aarav Uchoa', 4, 'El arco iris de el explorador'),
#  ('Fadhila Abadi', 2, 'El descubrimiento de la corrupción'),
#  ('Hiroko Zambrano', 4, 'El enigma de el tesoro'),
#  ('Darius Cruz', 3, 'El príncipe de la selva'),
#  ('Bianca Cruz', 3, 'El guardián de la isla'),
#  ('Vivek Abadi', 2, 'La historia de la caída'),
#  ('Xin Olivares', 3, 'El grito de la sirena'),
#  ('Vivek Ueno', 2, 'El arco iris de la batalla'),
#  ('Genghis Abadi', 2, 'El arco iris de el explorador'),
#  ('Yasmin Duarte', 2, 'El despertar de la sirena'),
#  ('Nadia Duarte', 5, 'El camino hacia el trono'),
#  ('Salim Quintana', 4, 'El destino de la promesa'),
#  ('Darya Oliveira', 2, 'El espejismo de la oscuridad'),
#  ('Pilar Esteves', 4, 'El lamento de el guerrero'),
#  ('Dmitri Tan', 4, 'El enigma de el tesoro'),
#  ('Mina Iglesias', 4, 'El eclipse de la maraña'),
#  ('Hiroko Ortega', 6, 'El arco iris de la batalla'),
#  ('Yuri Tan', 2, 'El descubrimiento de la esperanza'),
#  ('Orhan Inácio', 5, 'El bosque encantado de la bestia'),
#  ('Umberto Mendes', 2, 'La cripta de el lamento'),
#  ('Salim Rodriguez', 2, 'El tesoro escondido de la guerra'),
#  ('Alessandro Joaquim', 4, 'El renacimiento de el renacimiento'),
#  ('Tatiana Iglesias', 4, 'El castillo de el puente'),
#  ('Orhan Tan', 3, 'El despertar de el león'),
#  ('Ilya Carvalho', 5, 'El amanecer de el secreto'),
#  ('Zara Pereira', 4, 'El renacimiento de el vuelo'),
#  ('Fadhila Cruz', 2, 'El prisionero de el caos'),
#  ('Pilar Xia', 3, 'El amanecer de el puente'),
#  ('Hanako Yan', 3, 'El destino de la promesa'),
#  ('Zoya Xia', 4, 'El prisionero de el puente'),
#  ('Lakshmi Lopez', 7, 'El bosque encantado de el desafío'),
#  ('Rania Figueiredo', 5, 'El descubrimiento de la corrupción'),
#  ('Umar Diniz', 2, 'El pacto de la estrella'),
#  ('Han Janssen', 4, 'El hechizo de la aldea'),
#  ('Zara Teixeira', 2, 'El ritual de el lamento'),
#  ('Omar Lopez', 3, 'El último viaje de el laberinto'),
#  ('Rosa Abadi', 5, 'El enigma de la noche'),
#  ('Sakura Petrov', 5, 'El descubrimiento de el lobo'),
#  ('Xavier Goncalves', 2, 'La danza macabra de la ciudad'),
#  ('Xavier Santos', 5, 'El arco iris de la traición'),
#  ('Tatiana Goncalves', 4, 'La batalla de la resistencia'),
#  ('Ximena Vieira', 2, 'La rebelión de el grito'),
#  ('Parvati Carvalho', 2, 'El arco iris de la ciudad'),
#  ('Patricia Jimenez', 3, 'El secreto de la gárgola'),
#  ('Parvati Martinez', 3, 'El hechizo de la luz'),
#  ('Darya Hernandez', 3, 'El misterio de la guerra'),
#  ('Wang Wu', 2, 'La estrella fugaz de la luz'),
#  ('Orhan Inácio', 2, 'El amanecer de la magia'),
#  ('Theresa Zapata', 4, 'El hechizo de la aldea'),
#  ('Natalia Lima', 2, 'El prisionero de la pesadilla'),
#  ('Quintus Joaquim', 2, 'El secreto de la gárgola'),
#  ('Yasmin Bianchi', 5, 'El arco iris de el amor'),
#  ('Hanako Carvalho', 4, 'El tesoro escondido de el vuelo'),
#  ('Hiroko Ramos', 4, 'El eclipse de la reina'),
#  ('Chen Pereira', 3, 'La batalla de la caverna'),
#  ('Umberto Qian', 2, 'La misión de la gruta'),
#  ('Quentin Teles', 2, 'El enigma de la noche'),
#  ('Rosa Figueiredo', 2, 'La danza de la pasión'),
#  ('Zara Etxebarria', 8, 'El amanecer de la senda'),
#  ('Chiyoko Duarte', 2, 'La fuga de la redención'),
#  ('Darius Borges', 4, 'El misterio de el laberinto'),
#  ('Vivek Pereira', 2, 'El vuelo mágico de la soledad'),
#  ('Fadhila Almeida', 4, 'El despertar de el león'),
#  ('Quintus Oliveira', 4, 'El vuelo de la sombra'),
#  ('Tatiana Ortega', 3, 'La canción de la expedición'),
#  ('Oscar Vargas', 3, 'El bosque encantado de el desafío'),
#  ('Rashid Vieira', 2, 'El camino hacia el trono'),
#  ('Quentin Nguyen', 2, 'El resurgimiento de el rincón'),
#  ('Zafar Wu', 4, 'El bosque encantado de el jardín'),
#  ('Zara Bianchi', 3, 'El despertar de el león'),
#  ('Sakura Ivanov', 2, 'El hechizo de la luz'),
#  ('Elif Xavier', 2, 'El grito de la sirena'),
#  ('Pilar Sousa', 2, 'El descubrimiento de el lobo'),
#  ('Kamala Ortega', 2, 'El tesoro de el abismo'),
#  ('Kamala Correia', 5, 'El espejismo de el lamento')]

# %% [markdown]
# ### Consulta 9
#
# **Nombre de todos los actores que han participado sólo en películas dirigidas por el director con id\_director 1.**
#
#
# **Ejemplo:**
# |Nombre      |
# |------------|
# |Ryan Gosling|
# |...         |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */

# %% [markdown]
# ### Consulta BONUS
#
# **Nombre de todos los actores que nunca han ganado un premio, todas las películas en las que han participado y el nombre, número total de películas y número total de premios de los directores de cada película.**
#
#
# **Ejemplo:**
# |Nombre del actor|Nombre de la película|Nombre del director|Número de películas del director|Número de premios del director|
# |----------------|---------------------|-------------------|--------------------------------|-----------------------|
# |Mark Ruffalo    |Poor Things          |Yorgos Lanthimos   |4                               |0                      |
# |Saoirse Ronan   |Lady Bird            |Greta Gerwig       |20                              |1                      |
# |Saoirse Ronan   |Little Women         |Greta Gerwig       |20                              |1                      |
# |...             |...                  |...                |...                             |...                    |
#
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=cafe4e99-499e-4e36-b9fd-48e2d31e0196' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
